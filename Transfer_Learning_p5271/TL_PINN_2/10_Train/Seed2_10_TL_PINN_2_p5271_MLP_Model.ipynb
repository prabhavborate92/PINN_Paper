# %%
# Load Libraries 
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
from keras.utils.vis_utils import plot_model
from keras.models import load_model
np.random.seed(10)   
tf.random.set_seed(10)

# %%
# Mount Google Drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]  
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/Data/p5271_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/Data/p5271MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel(), })
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel(),'physics_out':data1['physics_out'].ravel()}) 
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(), 'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt', 'C_filt','V_filt','Time','V','SS','physics_out']]
df_SS = df[['freqQAmpI_filt', 'C_filt', 'SS']] 
df_V = df[['freqQAmpI_filt', 'C_filt', 'V_filt']] 
df_PhyOut = df[['freqQAmpI_filt', 'C_filt', 'physics_out']] 
df_A = df[['freqQAmpI_filt','C_filt','freqQAmpI_filt']]
df_WV = df[['freqQAmpI_filt','C_filt','C_filt']]
xdf = df[['freqQAmpI_filt', 'C_filt']]
ydf = df[['SS','V_filt']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#         freqQAmpI_filt       C_filt
# 0        86444.183014  5713.739611
# 1        86444.358094  5713.748279
# 2        86442.647757  5713.750421
# 3        86419.380962  5713.758606
# 4        86414.552286  5713.772870
# ...               ...          ...
# 75994    81488.107323  5720.364457
# 75995    81375.846782  5720.365210
# 75996    81263.154871  5720.384980
# 75997    81137.502620  5720.393775
# 75998    80982.695515  5720.397332
#
# [75999 rows x 2 columns]
# Target Data:
#               SS     V_filt
# 0      5.893849  10.577261
# 1      5.893360  10.282278
# 2      5.893242  10.050505
# 3      5.893039   9.903014
# 4      5.892528   9.945154
# ...         ...        ...
# 75994  5.850977   0.674248
# 75995  5.851531   0.653177
# 75996  5.852108   0.863880
# 75997  5.852526   0.716388
# 75998  5.852725   0.863880
#
# [75999 rows x 2 columns]

# %%
# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (V)
arr = df_V.to_numpy()
n_steps = 300
xdf, ydf_V = create_timesteps(arr, n_steps)

# Preprocessing (Physics_Out)
arr = df_PhyOut.to_numpy()
n_steps = 300
xdf, phy_outdf = create_timesteps(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
n_steps = 300
xdf, Adf = create_timesteps(arr, n_steps)

# Preprocessing (WV)
arr = df_WV.to_numpy()
n_steps = 300
xdf, WVdf = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (V), Y = ', np.shape(ydf_V))
print('Target shape (A), Y = ', np.shape(Adf))
print('Target shape (WV), Y = ', np.shape(WVdf))
print('Target shape (Physics_Out), Y = ', np.shape(phy_outdf))

# Reshape 
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (75699, 300, 2)
# Target shape (SS), Y =  (75699,)
# Target shape (V), Y =  (75699,)
# Target shape (A), Y =  (75699,)
# Target shape (WV), Y =  (75699,)
# Target shape (Physics_Out), Y =  (75699,)
# After reshaping, X =  (75699, 600)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Split into train-val-test (V)
x_train, x_test, y_train_V, y_test_V = train_test_split(xdf, ydf_V, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_V, Y_val_V = train_test_split(x_train, y_train_V, test_size=0.125, shuffle=False)

# Split into train-val-test (A)
x_train, x_test, y_train_A, y_test_A= train_test_split(xdf, Adf, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_A, Y_val_A = train_test_split(x_train, y_train_A, test_size=0.125, shuffle=False)

# Split into train-val-test (WV)
x_train, x_test, y_train_WV, y_test_WV = train_test_split(xdf, WVdf, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_WV, Y_val_WV = train_test_split(x_train, y_train_WV, test_size=0.125, shuffle=False)

# Split into train-val-test (Physics Out)
x_train, x_test, y_train_Phy, y_test_Phy = train_test_split(xdf, phy_outdf, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_Phy, Y_val_Phy = train_test_split(x_train, y_train_Phy, test_size=0.125, shuffle=False)

# Select Train
X_train = X_train[45599:53199] 
Y_train_SS = Y_train_SS[45599:53199]
Y_train_V = Y_train_V[45599:53199]
Y_train_Phy = Y_train_Phy[45599:53199]
Y_train_A = Y_train_A[45599:53199]
Y_train_WV = Y_train_WV[45599:53199]

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 7390
# Validation samples: 7570
# Testing samples: 15140

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Normalize the output: V
scaler_v = MinMaxScaler()
Y_train_V = pd.DataFrame(scaler_v.fit_transform(Y_train_V.reshape(-1, 1)))
Y_val_V = pd.DataFrame(scaler_v.transform(Y_val_V.reshape(-1, 1)))
y_test_V = pd.DataFrame(scaler_v.transform(y_test_V.reshape(-1, 1)))

# %%
# # Normalize WV
scaler_wv = MinMaxScaler()
Y_train_WV = pd.DataFrame(scaler_wv.fit_transform(Y_train_WV.reshape(-1, 1)))
Y_val_WV = pd.DataFrame(scaler_wv.transform(Y_val_WV.reshape(-1, 1)))
y_test_WV = pd.DataFrame(scaler_wv.transform(y_test_WV.reshape(-1, 1)))

# %%
# # Normalize A
scaler_A = MinMaxScaler()
Y_train_A = pd.DataFrame(scaler_A.fit_transform(Y_train_A.reshape(-1, 1)))
Y_val_A = pd.DataFrame(scaler_A.transform(Y_val_A.reshape(-1, 1)))
y_test_A = pd.DataFrame(scaler_A.transform(y_test_A.reshape(-1, 1)))

# %%
# Time derivative function
ss1 = 0
def Time_Derivative(del_t,ss2):
    global ss1
    Gradient_Value = (ss2 - ss1) / (del_t)
    ss1 = ss2
    return Gradient_Value

# %% [markdown]
# **Define Physics-Informed Model**: **Self Learning Constants**

# %%
# Define Physics
class gradient_1(tf.keras.layers.Layer):
  def __init__(self,**kwargs):
    super(gradient_1,self).__init__()
    self.SS = tf.keras.layers.Dense(1)
    self.V = tf.keras.layers.Dense(1)
    self.A = tf.keras.layers.Dense(1)
    self.WV = tf.keras.layers.Dense(1)
    self.all_scale = tf.keras.layers.Dense(1)
    self.c1 = self.add_weight("c1",trainable=True)
    self.c2 = self.add_weight("c2",trainable=True)
    self.c3 = self.add_weight("c3",trainable=True)
    self.c4 = self.add_weight("c4",trainable=True)
    initializer = tf.keras.initializers.RandomUniform(10000,30000)
    self.c5 = self.add_weight("c5", initializer = initializer,trainable=True)

  def call(self, params):
    ss_pred, v_pred, Amp, wv = params 
    ss_pred = self.SS(ss_pred)
    v_pred = self.V(v_pred)
    Amp = self.A(Amp)
    wv = self.WV(wv)

    term1 = Time_Derivative(0.01,ss_pred)
    term2 = tf.divide(self.c2*Amp*self.c3*0.4*math.pi*wv,self.c5)
    term3 = self.c2*(tf.math.sqrt((1-(tf.divide(Amp,(self.c5)))**2)))
    term4 = tf.divide(math.pi*Amp*self.c3*0.4*wv,self.c5)
    term5 = term3+term4
    term6 = (self.c4-v_pred)
    term7 = tf.divide(1,self.c1)
    term8 = tf.divide(term2,term5)
    term9 = tf.multiply(term8,term6)
    term10 = tf.multiply(term1,term7)
    eqn = term10-term9
    eqn = self.all_scale(eqn)

    return eqn

# %%
# Load the pretrained model and re-fit
model = load_model('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_PINN_2/Exact_PINN_Transfer_model_70_10_20.h5', custom_objects={"gradient_1": gradient_1})

model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3))
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto') 
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_PINN_2/Check', monitor='val_loss', verbose=1, save_best_only=True, mode='min')  #Saves best model so far
callbacks_list = [earlystop]
start_time = time.time()
history = model.fit([X_train,Y_train_A,Y_train_WV],[Y_train_SS,Y_train_V,Y_train_Phy], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val,Y_val_A,Y_val_WV],[Y_val_SS,Y_val_V,Y_val_Phy]), verbose=1)
end_time = time.time()

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()

print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 7390 samples, validate on 7570 samples
# Epoch 1/100
# 7232/7390 [============================>.] - ETA: 0s - loss: 0.0170 - dense_5_loss: 0.0126 - dense_6_loss: 0.0043 - gradient_1_loss: 8.7310e-09
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 7390/7390 [==============================] - 1s 123us/sample - loss: 0.0167 - dense_5_loss: 0.0124 - dense_6_loss: 0.0043 - gradient_1_loss: 8.5421e-09 - val_loss: 0.0069 - val_dense_5_loss: 0.0053 - val_dense_6_loss: 0.0016 - val_gradient_1_loss: 1.2000e-12
# Epoch 2/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0056 - dense_5_loss: 0.0041 - dense_6_loss: 0.0016 - gradient_1_loss: 4.0544e-13 - val_loss: 0.0071 - val_dense_5_loss: 0.0051 - val_dense_6_loss: 0.0020 - val_gradient_1_loss: 2.4588e-14
# Epoch 3/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0050 - dense_5_loss: 0.0036 - dense_6_loss: 0.0014 - gradient_1_loss: 8.5491e-15 - val_loss: 0.0055 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 0.0012 - val_gradient_1_loss: 1.8411e-16
# Epoch 4/100
# 7390/7390 [==============================] - 1s 70us/sample - loss: 0.0047 - dense_5_loss: 0.0034 - dense_6_loss: 0.0013 - gradient_1_loss: 6.3607e-17 - val_loss: 0.0049 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 0.0011 - val_gradient_1_loss: 6.6120e-18
# Epoch 5/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0043 - dense_5_loss: 0.0031 - dense_6_loss: 0.0012 - gradient_1_loss: 2.1560e-17 - val_loss: 0.0052 - val_dense_5_loss: 0.0042 - val_dense_6_loss: 0.0011 - val_gradient_1_loss: 1.3071e-17
# Epoch 6/100
# 7390/7390 [==============================] - 1s 71us/sample - loss: 0.0041 - dense_5_loss: 0.0029 - dense_6_loss: 0.0012 - gradient_1_loss: 6.1326e-10 - val_loss: 0.0061 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 0.0022 - val_gradient_1_loss: 9.5013e-11
# Epoch 7/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0039 - dense_5_loss: 0.0028 - dense_6_loss: 0.0011 - gradient_1_loss: 4.3973e-10 - val_loss: 0.0048 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 8.8922e-04 - val_gradient_1_loss: 1.9478e-10
# Epoch 8/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0038 - dense_5_loss: 0.0028 - dense_6_loss: 0.0011 - gradient_1_loss: 5.1134e-10 - val_loss: 0.0049 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 9.0863e-04 - val_gradient_1_loss: 2.1277e-13
# Epoch 9/100
# 7390/7390 [==============================] - 1s 75us/sample - loss: 0.0039 - dense_5_loss: 0.0027 - dense_6_loss: 0.0012 - gradient_1_loss: 6.2793e-10 - val_loss: 0.0046 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 8.1817e-04 - val_gradient_1_loss: 2.9173e-10
# Epoch 10/100
# 7390/7390 [==============================] - 1s 70us/sample - loss: 0.0034 - dense_5_loss: 0.0024 - dense_6_loss: 9.5702e-04 - gradient_1_loss: 1.4647e-09 - val_loss: 0.0056 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 0.0010 - val_gradient_1_loss: 1.3694e-10
# Epoch 11/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0032 - dense_5_loss: 0.0023 - dense_6_loss: 8.7504e-04 - gradient_1_loss: 1.2364e-10 - val_loss: 0.0052 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 0.0012 - val_gradient_1_loss: 1.5658e-13
# Epoch 12/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0031 - dense_5_loss: 0.0022 - dense_6_loss: 8.8946e-04 - gradient_1_loss: 9.5999e-10 - val_loss: 0.0046 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 8.4952e-04 - val_gradient_1_loss: 1.2343e-08
# Epoch 13/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0031 - dense_5_loss: 0.0022 - dense_6_loss: 9.3270e-04 - gradient_1_loss: 8.4604e-10 - val_loss: 0.0046 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 6.7701e-04 - val_gradient_1_loss: 9.0332e-09
# Epoch 14/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0031 - dense_5_loss: 0.0022 - dense_6_loss: 8.3265e-04 - gradient_1_loss: 3.6015e-10 - val_loss: 0.0053 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 0.0014 - val_gradient_1_loss: 2.6609e-13
# Epoch 15/100
# 7390/7390 [==============================] - 1s 69us/sample - loss: 0.0032 - dense_5_loss: 0.0022 - dense_6_loss: 0.0011 - gradient_1_loss: 6.3207e-10 - val_loss: 0.0053 - val_dense_5_loss: 0.0041 - val_dense_6_loss: 0.0012 - val_gradient_1_loss: 7.3993e-11
# Epoch 16/100
# 7390/7390 [==============================] - 1s 74us/sample - loss: 0.0029 - dense_5_loss: 0.0020 - dense_6_loss: 8.9537e-04 - gradient_1_loss: 8.7350e-10 - val_loss: 0.0051 - val_dense_5_loss: 0.0042 - val_dense_6_loss: 8.7771e-04 - val_gradient_1_loss: 5.6410e-15
# Epoch 17/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0028 - dense_5_loss: 0.0020 - dense_6_loss: 8.6515e-04 - gradient_1_loss: 7.5614e-10 - val_loss: 0.0043 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 9.5832e-04 - val_gradient_1_loss: 1.6029e-13
# Epoch 18/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0028 - dense_5_loss: 0.0019 - dense_6_loss: 9.4365e-04 - gradient_1_loss: 5.9482e-10 - val_loss: 0.0043 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 7.2472e-04 - val_gradient_1_loss: 6.5931e-10
# Epoch 19/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0027 - dense_5_loss: 0.0019 - dense_6_loss: 8.2939e-04 - gradient_1_loss: 7.1822e-10 - val_loss: 0.0055 - val_dense_5_loss: 0.0041 - val_dense_6_loss: 0.0014 - val_gradient_1_loss: 9.1059e-10
# Epoch 20/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0026 - dense_5_loss: 0.0018 - dense_6_loss: 8.2916e-04 - gradient_1_loss: 6.1299e-08 - val_loss: 0.0050 - val_dense_5_loss: 0.0042 - val_dense_6_loss: 7.9435e-04 - val_gradient_1_loss: 7.9411e-12
# Epoch 21/100
# 7390/7390 [==============================] - 1s 71us/sample - loss: 0.0027 - dense_5_loss: 0.0019 - dense_6_loss: 8.0543e-04 - gradient_1_loss: 1.9009e-12 - val_loss: 0.0050 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 0.0011 - val_gradient_1_loss: 2.1982e-13
# Epoch 22/100
# 7390/7390 [==============================] - 1s 74us/sample - loss: 0.0026 - dense_5_loss: 0.0018 - dense_6_loss: 8.4749e-04 - gradient_1_loss: 6.5115e-14 - val_loss: 0.0044 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 7.6131e-04 - val_gradient_1_loss: 4.0439e-15
# Epoch 23/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0026 - dense_5_loss: 0.0017 - dense_6_loss: 8.5481e-04 - gradient_1_loss: 1.1743e-15 - val_loss: 0.0045 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 7.9884e-04 - val_gradient_1_loss: 7.6669e-17
# Epoch 24/100
# 7390/7390 [==============================] - 1s 71us/sample - loss: 0.0026 - dense_5_loss: 0.0018 - dense_6_loss: 8.4073e-04 - gradient_1_loss: 1.5182e-17 - val_loss: 0.0049 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 0.0012 - val_gradient_1_loss: 6.9153e-19
# Epoch 25/100
# 7390/7390 [==============================] - 1s 72us/sample - loss: 0.0024 - dense_5_loss: 0.0017 - dense_6_loss: 7.3383e-04 - gradient_1_loss: 1.0043e-19 - val_loss: 0.0045 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 9.7676e-04 - val_gradient_1_loss: 2.5199e-21
# Epoch 26/100
# 7390/7390 [==============================] - 1s 74us/sample - loss: 0.0023 - dense_5_loss: 0.0016 - dense_6_loss: 7.4281e-04 - gradient_1_loss: 3.8094e-22 - val_loss: 0.0051 - val_dense_5_loss: 0.0042 - val_dense_6_loss: 8.6506e-04 - val_gradient_1_loss: 5.0036e-24
# Epoch 27/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0022 - dense_5_loss: 0.0015 - dense_6_loss: 7.3550e-04 - gradient_1_loss: 6.6105e-25 - val_loss: 0.0050 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 0.0010 - val_gradient_1_loss: 1.5131e-27
# Epoch 28/100
# 7390/7390 [==============================] - 1s 71us/sample - loss: 0.0023 - dense_5_loss: 0.0016 - dense_6_loss: 7.6768e-04 - gradient_1_loss: 4.5199e-28 - val_loss: 0.0048 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 8.4133e-04 - val_gradient_1_loss: 3.8800e-31
# Epoch 29/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0023 - dense_5_loss: 0.0015 - dense_6_loss: 7.7751e-04 - gradient_1_loss: 5.7668e-32 - val_loss: 0.0047 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 7.4847e-04 - val_gradient_1_loss: 6.3620e-35
# Epoch 30/100
# 7390/7390 [==============================] - 1s 122us/sample - loss: 0.0021 - dense_5_loss: 0.0014 - dense_6_loss: 6.8252e-04 - gradient_1_loss: 3.1856e-36 - val_loss: 0.0099 - val_dense_5_loss: 0.0065 - val_dense_6_loss: 0.0035 - val_gradient_1_loss: 0.0000e+00
# Epoch 31/100
# 7390/7390 [==============================] - 1s 110us/sample - loss: 0.0026 - dense_5_loss: 0.0017 - dense_6_loss: 8.5326e-04 - gradient_1_loss: 0.0000e+00 - val_loss: 0.0046 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 9.3892e-04 - val_gradient_1_loss: 0.0000e+00
# Epoch 32/100
# 7390/7390 [==============================] - 1s 79us/sample - loss: 0.0020 - dense_5_loss: 0.0013 - dense_6_loss: 6.8497e-04 - gradient_1_loss: 0.0000e+00 - val_loss: 0.0047 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 8.6705e-04 - val_gradient_1_loss: 0.0000e+00
# Epoch 33/100
# 7390/7390 [==============================] - 1s 118us/sample - loss: 0.0023 - dense_5_loss: 0.0016 - dense_6_loss: 7.3943e-04 - gradient_1_loss: 3.4929e-09 - val_loss: 0.0049 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 8.0130e-04 - val_gradient_1_loss: 1.1478e-08
# Epoch 34/100
# 7390/7390 [==============================] - 1s 70us/sample - loss: 0.0020 - dense_5_loss: 0.0014 - dense_6_loss: 6.0249e-04 - gradient_1_loss: 2.6214e-10 - val_loss: 0.0053 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 9.8110e-04 - val_gradient_1_loss: 2.0348e-15
# Epoch 35/100
# 7390/7390 [==============================] - 1s 73us/sample - loss: 0.0020 - dense_5_loss: 0.0014 - dense_6_loss: 6.1954e-04 - gradient_1_loss: 5.5944e-16 - val_loss: 0.0067 - val_dense_5_loss: 0.0055 - val_dense_6_loss: 0.0012 - val_gradient_1_loss: 1.5884e-16
# Epoch 36/100
# 7390/7390 [==============================] - 1s 74us/sample - loss: 0.0018 - dense_5_loss: 0.0013 - dense_6_loss: 5.4039e-04 - gradient_1_loss: 6.9522e-17 - val_loss: 0.0055 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 8.8712e-04 - val_gradient_1_loss: 1.0908e-17
# Epoch 37/100
# 7390/7390 [==============================] - 1s 74us/sample - loss: 0.0019 - dense_5_loss: 0.0013 - dense_6_loss: 6.1209e-04 - gradient_1_loss: 9.1667e-10 - val_loss: 0.0044 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 7.4801e-04 - val_gradient_1_loss: 2.8599e-14
# Epoch 37: early stopping
# ---Training time: 22.02324343 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train,Y_train_A,Y_train_WV])
y_predtrain_SS = np.array(y_predtrain)[0,] 
y_predtrain_V =np.array(y_predtrain)[1,] 

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS) 
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS)) 

train_r2_V = r2_score(Y_train_V,y_predtrain_V )
train_rmse_V = np.sqrt(mean_squared_error(Y_train_V, y_predtrain_V )) 

# Model Performance: Validation
y_predval = model.predict([X_val,Y_val_A,Y_val_WV])
y_predval_SS = np.array(y_predval)[0,] 
y_predval_V = np.array(y_predval)[1,] 

val_r2_SS = r2_score(Y_val_SS, y_predval_SS) 
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

val_r2_V = r2_score(Y_val_V, y_predval_V) 
val_rmse_V = np.sqrt(mean_squared_error(Y_val_V, y_predval_V)) 

# Model Performance: Testing
y_predtest = model.predict([x_test,y_test_A,y_test_WV])
y_predtest_SS =np.array(y_predtest)[0,] 
y_predtest_V = np.array(y_predtest)[1,] 

test_r2_SS = r2_score(y_test_SS,y_predtest_SS) 
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

test_r2_V = r2_score(y_test_V,y_predtest_V)
test_rmse_V = np.sqrt(mean_squared_error(y_test_V, y_predtest_V)) 

# Print R2 Results 
print("R2 scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_r2_SS , train_r2_V))
print("R2 scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_r2_SS , val_r2_V))
print("R2 scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_r2_SS , test_r2_V))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_rmse_SS , train_rmse_V))
print("RMSE scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_rmse_SS , val_rmse_V))
print("RMSE scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_rmse_SS , test_rmse_V))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# R2 scores: Train (SS) - 0.96357, Train (V) - 0.94103
# R2 scores: Validation (SS) - 0.91111, Validation (V) - 0.92735
# R2 scores: Testing (SS) - 0.70068, Testing (V) - 0.49413
# RMSE scores: Train (SS) - 0.03534, Train (V) - 0.02355
# RMSE scores: Validation (SS) - 0.06023, Validation (V) - 0.02731
# RMSE scores: Testing (SS) - 0.11981, Testing (V) - 0.08263

# %%
# Inverse scaling: SS 
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# Inverse scaling: V
Y_train_V = scaler_v.inverse_transform(Y_train_V)
Y_val_V = scaler_v.inverse_transform(Y_val_V)
y_test_V = scaler_v.inverse_transform(y_test_V)
y_predtrain_V = scaler_v.inverse_transform(y_predtrain_V)
y_predval_V = scaler_v.inverse_transform(y_predval_V)
y_predtest_V = scaler_v.inverse_transform(y_predtest_V)

# %%
# Overall plot: SS & V
ttime = df['Time'][n_steps:]
t1, testtime = train_test_split(ttime, test_size=0.2, shuffle=False)
traintime, valtime = train_test_split(t1, test_size=0.125, shuffle=False)

traintime = traintime[45599:53199] 

fig = plt.figure(1, figsize=(20,6))
plt.plot(ttime, ydf_SS)
plt.plot(traintime, y_predtrain_SS)
plt.plot(valtime, y_predval_SS)
plt.plot(testtime, y_predtest_SS)
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

fig = plt.figure(2, figsize=(20,6))
plt.plot(ttime, ydf_V)
plt.plot(traintime, y_predtrain_V)
plt.plot(valtime,  y_predval_V)
plt.plot(testtime, y_predtest_V)
plt.xlabel('Time (s)')
plt.ylabel('Slip Rate (um/s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

# %%
# # Individual plot: SS

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Shear Stress (MPa)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SS, y_predtrain_SS, 'Training data', '')
results_plot(2, valtime, Y_val_SS, y_predval_SS, 'Validation data', 'g')
results_plot(3, testtime, y_test_SS, y_predtest_SS, 'Testing data', 'r')

# %%
# # Individual plot: V

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Slip Rate (um/s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_V, y_predtrain_V, 'Training data', '')
results_plot(2, valtime, Y_val_V, y_predval_V, 'Validation data', 'g')
results_plot(3, testtime, y_test_V, y_predtest_V, 'Testing data', 'r')

# %%
# Extract Weights
names = [weight.name for layer in model.layers for weight in layer.weights]
weights = model.get_weights()

for name, weight in zip(names, weights):
    print(name, weight.shape)
# Out:
# dense/kernel:0 (600, 128)
# dense/bias:0 (128,)
# dense_1/kernel:0 (128, 64)
# dense_1/bias:0 (64,)
# dense_2/kernel:0 (64, 32)
# dense_2/bias:0 (32,)
# dense_3/kernel:0 (32, 16)
# dense_3/bias:0 (16,)
# dense_4/kernel:0 (16, 8)
# dense_4/bias:0 (8,)
# dense_5/kernel:0 (8, 1)
# dense_5/bias:0 (1,)
# dense_6/kernel:0 (8, 1)
# dense_6/bias:0 (1,)
# c1:0 ()
# c2:0 ()
# c3:0 ()
# c4:0 ()
# c5:0 ()
# gradient_1/dense/kernel:0 (1, 1)
# gradient_1/dense/bias:0 (1,)
# gradient_1/dense_1/kernel:0 (1, 1)
# gradient_1/dense_1/bias:0 (1,)
# gradient_1/dense_2/kernel:0 (1, 1)
# gradient_1/dense_2/bias:0 (1,)
# gradient_1/dense_3/kernel:0 (1, 1)
# gradient_1/dense_3/bias:0 (1,)
# gradient_1/dense_4/kernel:0 (1, 1)
# gradient_1/dense_4/bias:0 (1,)

# %%
# Display Weights
model.get_weights()
# Out:
# [array([[ 1.4723100e-03,  1.5368217e-01, -3.3495468e-01, ...,
#           1.7123361e-03,  1.9445291e-02, -1.2769240e-03],
#         [ 1.2617867e-02, -2.3233449e-01, -2.1644761e-01, ...,
#           3.9394189e-02, -2.0922331e-02,  7.1937203e-02],
#         [-4.2930879e-03, -5.5582326e-02, -1.8418828e-01, ...,
#           1.2059840e-03, -6.6089660e-02, -6.8099611e-02],
#         ...,
#         [ 2.5870809e-02,  1.2113246e+00,  4.8566928e+00, ...,
#          -2.0758208e-02,  1.3066348e-01,  1.4610826e-02],
#         [ 3.4561176e-02, -2.7097073e+00,  1.8905444e+00, ...,
#           3.8351767e-02, -1.2680976e-01,  6.4651268e-03],
#         [-1.3781126e-01,  1.0492013e+00,  6.0149179e+00, ...,
#          -1.2194658e-01,  1.7188285e-01, -2.4904164e-02]], dtype=float32),
#  array([-4.7676754e-03,  5.2320135e-01,  3.7157509e-01, -4.9754297e-03,
#         -1.6049996e-03,  1.6622777e-01,  0.0000000e+00,  3.0540276e-01,
#         -4.6251202e-03,  0.0000000e+00,  2.9997468e-01,  0.0000000e+00,
#         -4.1582156e-03,  1.5367849e-01, -8.1587834e-03,  0.0000000e+00,
#          3.6103210e-01,  0.0000000e+00,  3.2171166e-01,  3.2101813e-01,
#         -5.5469512e-03,  2.0241818e+00,  3.3076823e-01, -1.9703759e-02,
#          3.6881006e-01, -5.6435922e-03,  2.9270396e-01,  4.7452325e-01,
#          0.0000000e+00, -5.1251431e-03,  2.6888177e-01, -6.8343752e-03,
#          1.0164483e+00,  2.6307032e-01,  2.3662476e-01, -8.3466722e-03,
#          0.0000000e+00,  4.5552230e-01, -3.9342842e-03, -5.0577181e-03,
#         -1.4206449e-02,  4.2189929e-01,  4.3631378e-01,  1.1930589e-01,
#         -5.6035528e-03,  3.1201869e-01, -4.6828776e-03,  8.0626714e-01,
#         -5.0035936e-01,  0.0000000e+00,  0.0000000e+00, -3.6124475e-03,
#         -7.5666015e-03, -4.8213420e-04,  0.0000000e+00,  1.1100401e-01,
#          1.1476467e+00,  3.3567002e-01, -7.8031537e-03, -6.3521154e-03,
#         -9.0555819e-03, -4.9008024e-03,  0.0000000e+00,  0.0000000e+00,
#          2.4549167e-01, -3.8269483e-03,  0.0000000e+00,  0.0000000e+00,
#          3.2137042e-01,  2.6423714e-01,  3.3567744e-01,  0.0000000e+00,
#          0.0000000e+00, -1.2042104e-02,  1.1852388e+00, -1.3980030e+00,
#         -3.0427470e-03,  0.0000000e+00,  3.4535566e-01,  0.0000000e+00,
#          0.0000000e+00,  3.6015478e-01, -9.6411332e-03, -1.3946253e-03,
#         -4.8208083e-03, -1.0102251e+00,  3.4377325e-01,  4.2939991e-01,
#         -5.2090464e-03,  0.0000000e+00, -3.0575250e-03, -2.1990638e-03,
#         -5.3361552e-03,  3.0663198e-01, -2.0684402e-03,  5.2348343e-03,
#          3.7321797e-01,  2.7558151e-01, -5.5475994e-03,  3.3336368e-01,
#          3.4614113e-01, -2.0071633e-02,  2.6746219e-01,  4.6543273e-01,
#         -2.2412189e-03,  2.6692107e+00, -1.2048146e-02,  0.0000000e+00,
#          1.1318218e+00,  0.0000000e+00,  5.5204129e-01, -6.9553563e-03,
#          4.7201991e-01,  0.0000000e+00,  2.2676341e-01,  0.0000000e+00,
#         -4.9803057e-03,  0.0000000e+00, -9.9479361e-04,  5.5468994e-01,
#          0.0000000e+00, -8.0336593e-03,  0.0000000e+00,  7.7249713e-02,
#          3.1786481e-01, -6.0229953e-03,  3.5934076e-01, -1.2308303e-03],
#        dtype=float32),
#  array([[ 0.03401727,  0.04589419, -0.0323868 , ...,  0.08310571,
#           0.06603912,  0.04081205],
#         [ 0.00820619,  0.39394113,  0.4591238 , ..., -0.2748604 ,
#          -0.05697757,  0.19500746],
#         [-0.11931608, -1.2671407 , -0.77252793, ...,  0.19379152,
#           0.01927531, -0.3792247 ],
#         ...,
#         [ 0.0107117 ,  0.01227785, -0.0613584 , ..., -0.07395881,
#          -0.036545  ,  0.07971267],
#         [ 0.01327935,  0.01940514, -0.02268115, ...,  0.0605288 ,
#           0.00663982,  0.13804585],
#         [-0.04961926, -0.01072297, -0.07480087, ...,  0.01697687,
#           0.08274307,  0.03124304]], dtype=float32),
#  array([-0.08976848,  1.001735  ,  1.1124665 , -0.0633413 , -1.041896  ,
#          0.8204185 ,  0.907601  , -0.8340072 , -1.1262201 ,  0.27131385,
#          0.35225588, -0.07915689, -0.91275376, -0.0235077 ,  0.24458706,
#          0.2064821 ,  0.08287399, -0.09309873, -0.1105632 ,  0.6204507 ,
#         -0.01484881,  0.49893963,  0.5067892 ,  1.4698818 , -0.06165196,
#          1.2933583 ,  2.711615  ,  0.14913528, -0.36535656, -0.05781337,
#          0.39770505, -0.08379629, -1.393248  ,  2.1580133 ,  0.6845457 ,
#          0.13956347, -0.02535342, -0.08200961, -1.2890056 ,  1.109215  ,
#          0.31348953, -0.09692311,  2.7049086 , -0.2516736 , -0.07118701,
#          0.21294492, -1.0938002 , -0.11372659,  1.2376133 , -0.71484935,
#         -0.6783085 , -0.5446465 ,  0.88737416,  1.0750884 ,  1.5021198 ,
#          0.9188495 ,  0.14703946,  1.4518657 ,  0.31413394,  1.5341765 ,
#         -0.02708524,  0.02852188, -0.0735283 ,  1.3778137 ], dtype=float32),
#  array([[ 2.47421134e-02,  3.64002697e-02,  1.45268952e-02, ...,
#          -1.94353666e-02, -4.52577136e-02,  1.06496252e-02],
#         [-4.32834834e-01, -1.02797791e-01, -3.30952592e-02, ...,
#          -1.38779329e-02,  6.15418017e-01, -1.79763317e-01],
#         [-6.91138148e-01,  4.86833043e-03, -6.04689009e-02, ...,
#           3.81651946e-04, -9.32269394e-01,  2.47553829e-02],
#         ...,
#         [-6.51471674e-01, -2.54004691e-02, -1.10499434e-01, ...,
#          -2.60094199e-02, -8.72985363e-01, -4.55493806e-04],
#         [ 3.29976603e-02,  3.36380489e-02,  7.02075735e-02, ...,
#          -8.80942270e-02, -2.96075339e-03,  8.20957646e-02],
#         [-1.39147446e-01, -2.04603169e-02, -7.38672689e-02, ...,
#          -4.92313579e-02,  1.43007353e-01, -4.65694070e-02]], dtype=float32),
#  array([-0.42587408, -0.06109355, -0.08516049,  2.08904   , -0.07570688,
#         -0.05088365,  0.9189413 ,  0.46611232,  1.0332791 , -0.0729347 ,
#          1.2429947 , -0.05362248,  0.4943927 ,  0.7368156 ,  0.30546644,
#          0.87201303, -0.09903786, -0.05829313,  0.6057375 ,  1.3734977 ,
#         -0.11975481, -0.09411556, -0.02517985, -0.04466598,  1.4185901 ,
#         -0.10874543, -0.18795103,  1.2174922 , -0.05944584, -0.06029677,
#          0.6389918 , -0.10099596], dtype=float32),
#  array([[ 2.55486611e-02, -3.63456428e-01,  1.15187757e-01,
#           2.63181597e-01, -6.52543677e-04,  4.40172553e-01,
#           8.66340697e-02, -4.35014674e-03, -1.03025424e+00,
#          -9.06041622e-01, -7.28181824e-02, -7.53931850e-02,
#          -1.44857084e-02, -1.27819717e-01, -5.09391874e-02,
#          -1.33818448e-01],
#         [ 4.25996147e-02,  1.39917526e-02, -1.92176066e-02,
#           7.02875257e-02,  4.76931334e-02, -5.40053286e-02,
#          -7.10376725e-02,  1.23020662e-02, -2.98437420e-02,
#          -3.75776179e-02, -1.54235233e-02,  2.96128588e-03,
#          -2.48861145e-02,  3.76748368e-02, -7.63200819e-02,
#           9.04902965e-02],
#         [-1.57360032e-01, -6.15619682e-02, -2.13105530e-02,
#           4.43157367e-03, -8.40598345e-02,  3.23892459e-02,
#           1.12899296e-01,  5.75683825e-02, -2.22432595e-02,
#          -3.46800573e-02,  2.21051648e-02, -8.70221853e-03,
#          -5.58246560e-02, -8.18920359e-02, -4.34761085e-02,
#          -3.35879950e-03],
#         [-1.47198826e-01,  3.81141365e-01,  2.58022159e-01,
#          -3.55800390e-02, -3.33996862e-01, -3.31218868e-01,
#           5.74215613e-02,  2.01490536e-01,  7.19934106e-02,
#           3.50649171e-02, -2.34630629e-02,  3.52453768e-01,
#          -5.61822504e-02,  6.07526526e-02, -1.69388484e-02,
#          -2.41735265e-01],
#         [ 3.86139899e-02,  6.17355327e-05, -3.24568748e-02,
#          -7.39378929e-02,  7.21262172e-02, -3.63535597e-03,
#          -6.20207377e-02,  1.86489429e-02,  5.48507236e-02,
#          -1.95654519e-02, -8.41554534e-03,  7.91062191e-02,
#           2.19589419e-04,  2.96806544e-03, -6.46293536e-03,
#           4.43068445e-02],
#         [-3.26167718e-02, -7.20123947e-02,  7.01627731e-02,
#          -5.40233664e-02, -8.93884245e-03,  2.51120292e-02,
#          -1.24743991e-01,  5.79448156e-02,  1.28090503e-02,
#          -3.24400105e-02,  8.88235718e-02, -5.39760329e-02,
#          -3.71310785e-02,  4.87358980e-02, -5.39820455e-02,
#           4.50529531e-02],
#         [-1.16566703e-01, -1.37071192e-01, -8.00886810e-01,
#          -5.07834733e-01, -7.13613153e-01, -1.68576965e-03,
#          -4.42695558e-01,  3.88697274e-02,  9.90422070e-02,
#           2.58316129e-01, -2.05142424e-02, -3.78623158e-01,
#          -6.93479031e-02,  4.38959330e-01, -5.02424128e-02,
#           1.29289001e-01],
#         [-5.56109369e-01, -2.77429432e-01, -4.25043255e-01,
#          -1.18020125e-01, -1.27224401e-01, -1.64766192e-01,
#           1.56545527e-02, -7.27112740e-02, -3.44850570e-01,
#          -3.69129963e-02, -4.77094986e-02, -3.56885977e-02,
#          -2.79484633e-02,  3.57003599e-01, -6.60182089e-02,
#           6.37746975e-02],
#         [-3.74182686e-02, -5.60792923e-01, -1.10664463e+00,
#          -6.07156396e-01, -4.55327988e-01, -1.90643892e-01,
#           7.53903687e-02,  3.72340173e-01,  4.46337759e-02,
#          -2.26542652e-01, -8.39641690e-03,  3.28086354e-02,
#          -6.42803758e-02, -1.77305236e-01, -6.93462268e-02,
#           1.02662459e-01],
#         [-2.56366432e-02,  4.08730879e-02, -7.49691529e-03,
#           5.99279292e-02, -1.11593017e-02,  4.82415669e-02,
#          -2.98919268e-02, -1.32448217e-02,  1.10856127e-02,
#           4.24359404e-02, -6.75384104e-02, -8.36390816e-03,
#          -1.41481170e-02,  2.07836376e-04,  5.94104547e-03,
#          -1.92757845e-02],
#         [ 5.41912057e-02,  1.42444521e-01,  7.76537731e-02,
#           1.34581387e-01,  4.60724123e-02, -1.08494267e-01,
#          -5.15509993e-02, -1.95796952e-01, -1.29179105e-01,
#          -2.19349563e-01, -1.58910602e-02, -1.18640780e-01,
#          -3.22757997e-02, -4.56860289e-02, -1.42417341e-01,
#          -8.22377801e-02],
#         [ 6.12370903e-03, -3.27207241e-03,  6.58958917e-03,
#          -2.33977363e-02,  1.51841687e-02, -3.01975179e-02,
#          -2.80526560e-02,  7.92304426e-03, -6.35259077e-02,
#          -3.09319384e-02,  5.91961853e-02, -8.94536301e-02,
#           2.40734424e-02, -6.07771464e-02, -3.82002816e-02,
#          -8.70752335e-02],
#         [-3.53074193e-01, -1.25306383e-01, -7.63363019e-02,
#          -5.72285429e-02, -5.36695540e-01, -5.97405195e-01,
#           3.73778671e-01, -1.09282419e-01, -1.47734535e+00,
#           9.00901705e-02,  8.85794591e-03, -6.48777857e-02,
#          -5.21140844e-02, -5.62341213e-01, -1.81355029e-02,
#           1.42367005e-01],
#         [-9.26167667e-01, -1.56541571e-01,  1.08916081e-01,
#          -3.99763398e-02, -6.28245890e-01,  3.65107879e-02,
#           3.33098412e-01, -5.12217939e-01, -2.64234185e-01,
#           3.68802175e-02, -5.23845144e-02,  2.21899241e-01,
#          -3.82004008e-02, -2.11630657e-01, -1.39471488e-02,
#          -1.35369763e-01],
#         [-5.52185416e-01, -6.82532072e-01, -3.85520935e-01,
#          -6.78771257e-01, -2.99276531e-01, -9.45300579e-01,
#          -1.01011544e-01, -1.44511342e-01, -2.25511953e-01,
#          -5.66463321e-02, -4.31514308e-02,  5.35196029e-02,
#          -1.22380562e-01, -7.35718384e-02, -8.06375518e-02,
#          -1.45410940e-01],
#         [ 3.66862476e-01, -1.33861673e+00, -9.70645130e-01,
#          -3.58097166e-01, -5.82954943e-01, -3.40490252e-01,
#          -3.12155873e-01, -2.39840299e-01, -5.66842221e-02,
#          -1.21945918e-01, -5.10938764e-02, -6.51682168e-02,
#          -1.12293027e-01,  2.30647475e-02, -8.39579329e-02,
#          -9.68169570e-02],
#         [ 8.09625760e-02,  7.23645538e-02, -6.25123382e-02,
#           7.67157879e-03,  6.07795641e-02, -7.29143098e-02,
#           1.46169523e-02, -6.19469807e-02,  1.44086676e-02,
#          -3.41011696e-02, -1.32713187e-02, -9.97229218e-02,
#           5.20254560e-02,  9.25445780e-02,  5.06881997e-03,
#           1.00359894e-01],
#         [ 6.58756867e-03,  1.89204141e-02, -1.99800488e-02,
#          -7.33414618e-03, -4.69975807e-02, -3.33151594e-02,
#           4.41669114e-02, -3.59235071e-02,  3.72544373e-03,
#          -7.19827563e-02,  4.95810471e-02,  2.27524899e-02,
#           4.70578447e-02, -7.50028202e-03, -8.11224505e-02,
#          -2.60708332e-02],
#         [-2.53688812e-01, -1.10765494e-01, -4.55560625e-01,
#          -3.85643303e-01, -1.22456563e+00, -1.44257486e-01,
#          -3.19967240e-01, -2.23171249e-01, -1.03706509e-01,
#           5.85648464e-03, -2.74677332e-02,  9.82477814e-02,
#          -5.27020916e-03,  2.32622609e-01, -7.31421635e-02,
#          -3.36953163e-01],
#         [ 2.29254529e-01, -2.03949109e-01,  1.77861795e-01,
#           2.32715338e-01,  1.10067621e-01,  5.10623276e-01,
#           1.50857106e-01, -6.26527429e-01, -9.68855172e-02,
#          -1.11509643e-01, -1.32922549e-02,  3.25331427e-02,
#          -6.80557117e-02, -4.10363674e-01, -5.51042110e-02,
#           3.92645389e-01],
#         [ 1.90615784e-02,  3.14675421e-02,  1.73511282e-02,
#           2.43037269e-02,  5.82760721e-02,  1.61810201e-02,
#           1.20491646e-02,  2.88010910e-02, -3.26483622e-02,
#          -4.00581444e-03,  9.34594721e-02, -2.27657985e-02,
#           6.29830584e-02,  1.28603131e-01, -3.59095261e-03,
#          -1.14322416e-01],
#         [ 8.28092569e-04, -6.25984417e-03,  1.48140462e-02,
#           5.02523035e-02, -7.73518980e-02, -7.92248733e-03,
#           7.79904649e-02,  2.68282443e-02, -3.69515247e-03,
#          -3.98022942e-02,  8.73780902e-03, -1.91998743e-02,
#          -2.46906187e-02,  7.20253214e-02,  1.01890229e-01,
#          -5.04120402e-02],
#         [ 4.03420515e-02,  1.73357055e-02,  1.05929503e-03,
#          -4.85005826e-02,  3.37226316e-02, -2.96254195e-02,
#           1.94527172e-02,  1.78412218e-02,  2.56785881e-02,
#           1.46130649e-02, -5.66381626e-02, -3.32327820e-02,
#           2.90053487e-02, -5.04349498e-03,  3.30742113e-02,
#          -3.42427827e-02],
#         [ 1.18298689e-02,  5.52873611e-02, -1.71570003e-03,
#          -4.74193739e-03,  2.52756216e-02, -7.82937631e-02,
#           1.59198269e-02, -5.00791483e-02, -4.17619199e-03,
#           5.82793616e-02,  3.92585471e-02, -1.76796298e-02,
#          -7.33841509e-02,  2.87760212e-03,  5.81883602e-02,
#          -1.84072293e-02],
#         [ 3.51341665e-01, -8.19353238e-02,  8.34780782e-02,
#           2.96715170e-01,  5.02324939e-01, -1.78083871e-02,
#           1.25134274e-01, -2.89312214e-01, -6.62092388e-01,
#           1.05349272e-01, -6.34174794e-02, -4.71442705e-03,
#          -4.44836803e-02, -8.17034543e-02, -1.37178618e-02,
#           1.30035266e-01],
#         [ 1.45659437e-02,  2.07522549e-02, -4.31461900e-01,
#          -2.10747823e-01, -4.54960912e-02,  9.78014767e-02,
#           1.61018565e-01, -1.08606234e-01, -2.38915011e-01,
#          -2.44962871e-01, -2.55603287e-02,  1.46679729e-01,
#           1.90508496e-02,  1.50126979e-01,  7.68528203e-04,
#           3.72307226e-02],
#         [-7.73541272e-01,  1.29407257e-01, -2.58322626e-01,
#          -3.47351134e-01,  2.23747939e-01,  2.63041824e-01,
#          -9.99676883e-02,  2.70138741e-01,  3.98692578e-01,
#          -1.84800401e-02, -1.00008836e-02, -2.15892076e-01,
#           9.90293338e-04,  3.24357748e-02,  4.14280966e-03,
#          -7.74401203e-02],
#         [ 3.44672054e-01, -4.32156116e-01, -7.48856306e-01,
#          -3.86928141e-01, -4.46356803e-01,  3.26168537e-01,
#           6.08171485e-02, -2.72537559e-01, -4.46054041e-01,
#           1.90841615e-01, -6.69784993e-02,  2.63099760e-01,
#          -4.00160477e-02,  5.84903359e-02,  1.56433992e-02,
#          -3.69563289e-02],
#         [ 8.74876697e-03, -8.94707665e-02,  6.17618719e-03,
#           2.83607300e-02,  6.21870235e-02, -5.89808524e-02,
#          -2.74093319e-02, -4.47062887e-02,  2.50207987e-02,
#          -3.94974276e-02,  2.16923282e-03,  3.55116837e-02,
#           5.59592843e-02,  8.83410424e-02,  1.56474416e-03,
#           5.97243235e-02],
#         [-1.69986219e-03, -5.18325754e-02, -7.69542083e-02,
#          -3.38648073e-02, -6.49013892e-02, -3.28008644e-02,
#           4.24117111e-02, -1.38012335e-01,  4.21672873e-02,
#          -3.69500220e-02,  5.61509840e-02, -1.49277896e-02,
#           6.44987449e-02, -2.20051948e-02, -1.50949555e-02,
#           2.00743303e-02],
#         [ 1.15852013e-01, -1.89209566e-01, -6.78623259e-01,
#          -4.18832935e-02,  3.30112390e-02, -3.42388898e-01,
#          -2.13675667e-02, -5.64534999e-02,  2.43223399e-01,
#           4.67621908e-02, -1.51653355e-02, -9.50032398e-02,
#          -2.35694740e-03, -4.72216517e-01, -9.94368196e-02,
#           1.64037809e-01],
#         [-2.38381326e-02, -2.94525232e-02, -2.64294893e-02,
#           4.69122715e-02, -3.15664560e-02, -3.08645330e-02,
#          -6.26100376e-02, -6.89921007e-02,  2.01692935e-02,
#          -4.22266126e-02, -2.02302132e-02,  1.00932559e-02,
#          -3.48066948e-02,  6.36823177e-02, -1.26724942e-02,
#           4.66608778e-02]], dtype=float32),
#  array([ 0.01151679,  1.4321779 ,  0.5524597 ,  0.75304747,  0.5900151 ,
#         -1.5797029 , -0.15848543,  1.1351258 , -0.539422  , -0.16831121,
#         -0.12198155,  0.32579362, -0.09583407,  0.12893996, -0.12629166,
#          1.6452538 ], dtype=float32),
#  array([[ 0.03506548,  0.01691703,  0.00417344, -0.07909875, -0.040114  ,
#          -0.00472067, -0.0532721 , -0.1144426 ],
#         [-0.11665968, -0.03357791,  0.22577494,  0.34737906, -0.0197442 ,
#          -0.07036183, -0.40069267, -0.00607116],
#         [ 0.03973807,  0.01173609,  0.17541514,  0.01855989, -0.0014056 ,
#          -0.07034909, -0.33816147,  0.02645934],
#         [-0.02885298, -0.05773927,  0.2648744 ,  0.03509326, -0.05043634,
#          -0.13913116, -0.3822414 , -0.11226101],
#         [-0.05302539, -0.01503846, -0.23831528, -0.11372848, -0.04735407,
#           0.02455006,  0.3970217 ,  0.12328196],
#         [-0.02598021, -0.03756904,  0.18264855,  0.21127678, -0.03550718,
#          -0.11839895, -0.15350346,  0.11855058],
#         [ 0.02643177, -0.11405961,  0.11585529, -0.29335928, -0.20279615,
#          -0.00749872,  0.25142083, -0.10583913],
#         [-0.15676562, -0.06200937, -0.10870088,  0.19863784, -0.08574422,
#           0.00290328,  0.00120085, -0.00848659],
#         [-0.42886537, -0.1422569 , -0.16684744,  0.21753226,  0.0211114 ,
#          -0.07483561,  0.05205977,  0.01674402],
#         [-0.08702409, -0.00985761, -0.25268266,  0.45437118, -0.10478176,
#           0.01136974, -0.12325915,  0.08244474],
#         [ 0.03812319,  0.02996353,  0.02037499,  0.00428838, -0.12214774,
#           0.08100948, -0.01378886,  0.07210568],
#         [ 0.07849204, -0.09794403, -0.15070404, -0.14906347, -0.25466043,
#          -0.03528202, -0.09905224, -0.06259847],
#         [-0.0066361 ,  0.08705796,  0.01431335,  0.02778458,  0.02301127,
#           0.03244352,  0.01134282, -0.05471162],
#         [-0.10831394, -0.04657811, -0.5552958 , -0.065011  , -0.04681168,
#          -0.07556397, -0.27235702, -0.10415602],
#         [-0.03141854,  0.02197623, -0.04655175, -0.03603095, -0.06905179,
#           0.02578464, -0.02571326,  0.0187281 ],
#         [-0.13751318, -0.0659952 , -0.05322963, -0.2503089 ,  0.01326327,
#           0.00409634, -0.12118126, -0.13762216]], dtype=float32),
#  array([ 0.78483653, -0.07203116,  0.3458049 ,  0.27900732, -0.10543936,
#         -0.08455205,  0.26579657, -0.05667354], dtype=float32),
#  array([[ 0.3097548 ],
#         [-0.0332691 ],
#         [-0.05425992],
#         [-0.16091257],
#         [ 0.00895535],
#         [ 0.00483771],
#         [-0.05628462],
#         [-0.07154004]], dtype=float32),
#  array([0.5642753], dtype=float32),
#  array([[ 0.00390681],
#         [ 0.00034625],
#         [ 0.19160202],
#         [ 0.00485172],
#         [-0.03136542],
#         [-0.10287938],
#         [ 0.07104249],
#         [-0.07778971]], dtype=float32),
#  array([0.07597363], dtype=float32),
#  2.7385466,
#  -0.7959952,
#  0.78129154,
#  0.36824775,
#  20277.303,
#  array([[0.00067549]], dtype=float32),
#  array([-0.00045297], dtype=float32),
#  array([[0.17495264]], dtype=float32),
#  array([-0.06205375], dtype=float32),
#  array([[-1.2220724]], dtype=float32),
#  array([-0.04561242], dtype=float32),
#  array([[-0.7389875]], dtype=float32),
#  array([-0.04922188], dtype=float32),
#  array([[-1.296549e-06]], dtype=float32),
#  array([-1.6766428e-07], dtype=float32)]

# %%
# ML Learned Constants

# Normal Stress
r1 = 10/6.1
cols = ['NS']
data = pd.DataFrame(np.array([[2.88]]),columns=cols)
NS = scaler_ss.inverse_transform(data)
NS = NS*r1

# Shear Loading Velocity
dt = 0.01
cols = ['VL']
data = pd.DataFrame(np.array([[0.80]]),columns=cols)
VL = scaler_v.inverse_transform(data)
VL = (VL*dt)*2*r1

# Loading Stiffness
K = (((0.37)/10)/r1)*2

# Density (kg/cm3)
rho = (0.7813*10*1000)/(2*r1)

print("Normal Stress:",NS)
print("Shear Loading Velocity:",VL)
print("Loading Stiffness:",K)
print("Density:",rho)
print("A_Intact:",20277)
# Out:
# Normal Stress: [[11.67551432]]
# Shear Loading Velocity: [[7.41064587]]
# Loading Stiffness: 0.04514
# Density: 2382.965
# A_Intact: 20277

# %%
# # Extract Data

# # Time 
# savetxt('Whole_time.csv', ttime, delimiter=',')
# savetxt('traintime.csv', traintime, delimiter=',')
# savetxt('valtime.csv', valtime, delimiter=',')
# savetxt('testtime.csv', testtime, delimiter=',')

# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# # V
# savetxt('Y_train_V.csv', Y_train_V, delimiter=',')
# savetxt('Y_val_V.csv', Y_val_V, delimiter=',')
# savetxt('y_test_V.csv', y_test_V, delimiter=',')
# savetxt('y_predtrain_V.csv', y_predtrain_V, delimiter=',')
# savetxt('y_predval_V.csv', y_predval_V, delimiter=',')
# savetxt('y_predtest_V.csv', y_predtest_V, delimiter=',')

# # Download
# files.download('Whole_time.csv')
# files.download('traintime.csv')
# files.download('valtime.csv')
# files.download('testtime.csv')

# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')

# files.download('Y_train_V.csv')
# files.download('Y_val_V.csv')
# files.download('y_test_V.csv')
# files.download('y_predtrain_V.csv')
# files.download('y_predval_V.csv')
# files.download('y_predtest_V.csv')

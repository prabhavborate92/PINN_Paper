# %%
# Load Libraries 
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
from keras.utils.vis_utils import plot_model
from keras.models import load_model
np.random.seed(0)   
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]  
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %% [markdown]
# **# Transfer Learning: p5271 #**

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/Data/p5271_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/Data/p5271MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel()})
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel()}) 
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(), 'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt', 'C_filt','Time','V_filt','SS']]
df_SS = df[['freqQAmpI_filt','C_filt','SS']] 
df_V = df[['freqQAmpI_filt','C_filt','V_filt']] 
df_A = df[['freqQAmpI_filt','C_filt','freqQAmpI_filt']]
df_WV = df[['freqQAmpI_filt','C_filt','C_filt']]
xdf = df[['freqQAmpI_filt', 'C_filt']]
ydf = df[['SS','V_filt']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#         freqQAmpI_filt       C_filt
# 0        86444.183014  5713.739611
# 1        86444.358094  5713.748279
# 2        86442.647757  5713.750421
# 3        86419.380962  5713.758606
# 4        86414.552286  5713.772870
# ...               ...          ...
# 75994    81488.107323  5720.364457
# 75995    81375.846782  5720.365210
# 75996    81263.154871  5720.384980
# 75997    81137.502620  5720.393775
# 75998    80982.695515  5720.397332
#
# [75999 rows x 2 columns]
# Target Data:
#               SS     V_filt
# 0      5.893849  10.577261
# 1      5.893360  10.282278
# 2      5.893242  10.050505
# 3      5.893039   9.903014
# 4      5.892528   9.945154
# ...         ...        ...
# 75994  5.850977   0.674248
# 75995  5.851531   0.653177
# 75996  5.852108   0.863880
# 75997  5.852526   0.716388
# 75998  5.852725   0.863880
#
# [75999 rows x 2 columns]

# %%
# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (V)
arr = df_V.to_numpy()
n_steps = 300
xdf, ydf_V = create_timesteps(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
n_steps = 300
xdf, ydf_A = create_timesteps(arr, n_steps)

# Preprocessing (WV)
arr = df_WV.to_numpy()
n_steps = 300
xdf, ydf_WV = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (V), Y = ', np.shape(ydf_V))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (75699, 300, 2)
# Target shape (SS), Y =  (75699,)
# Target shape (V), Y =  (75699,)
# After reshaping, X =  (75699, 600)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Split into train-val-test (V)
x_train, x_test, y_train_V, y_test_V = train_test_split(xdf, ydf_V, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_V, Y_val_V = train_test_split(x_train, y_train_V, test_size=0.125, shuffle=False)

# Select Training Data Percentage 
X_train = X_train[15200:53199]
Y_train_SS = Y_train_SS[15200:53199]
Y_train_V = Y_train_V[15200:53199]

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 37789
# Validation samples: 7570
# Testing samples: 15140

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Normalize the output: V
scaler_v = MinMaxScaler()
Y_train_V = pd.DataFrame(scaler_v.fit_transform(Y_train_V.reshape(-1, 1)))
Y_val_V = pd.DataFrame(scaler_v.transform(Y_val_V.reshape(-1, 1)))
y_test_V = pd.DataFrame(scaler_v.transform(y_test_V.reshape(-1, 1)))

# %%
# Load the pretrained model and re-fit
model = load_model('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/DD_Transfer_model_70_10_20.h5')

model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3))
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')  
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check', monitor='val_loss', verbose=1, save_best_only=True, mode='min')  #Saves best model so far
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS,Y_train_V], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS,Y_val_V]), verbose=1)
end_time = time.time()

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()

print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 37789 samples, validate on 7570 samples
# Epoch 1/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0114 - dense_5_loss: 0.0080 - dense_6_loss: 0.0034
# Epoch 1: val_loss improved from inf to 0.00738, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 4s 99us/sample - loss: 0.0114 - dense_5_loss: 0.0080 - dense_6_loss: 0.0034 - val_loss: 0.0074 - val_dense_5_loss: 0.0061 - val_dense_6_loss: 0.0013
# Epoch 2/100
# 36800/37789 [============================>.] - ETA: 0s - loss: 0.0049 - dense_5_loss: 0.0040 - dense_6_loss: 9.4239e-04
# Epoch 2: val_loss did not improve from 0.00738
# 37789/37789 [==============================] - 2s 47us/sample - loss: 0.0049 - dense_5_loss: 0.0039 - dense_6_loss: 9.4259e-04 - val_loss: 0.0087 - val_dense_5_loss: 0.0071 - val_dense_6_loss: 0.0016
# Epoch 3/100
# 37312/37789 [============================>.] - ETA: 0s - loss: 0.0041 - dense_5_loss: 0.0033 - dense_6_loss: 8.0880e-04
# Epoch 3: val_loss improved from 0.00738 to 0.00553, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 75us/sample - loss: 0.0041 - dense_5_loss: 0.0033 - dense_6_loss: 8.0338e-04 - val_loss: 0.0055 - val_dense_5_loss: 0.0048 - val_dense_6_loss: 7.6978e-04
# Epoch 4/100
# 36928/37789 [============================>.] - ETA: 0s - loss: 0.0037 - dense_5_loss: 0.0029 - dense_6_loss: 7.1062e-04
# Epoch 4: val_loss improved from 0.00553 to 0.00511, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 68us/sample - loss: 0.0037 - dense_5_loss: 0.0029 - dense_6_loss: 7.1985e-04 - val_loss: 0.0051 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 7.9406e-04
# Epoch 5/100
# 37568/37789 [============================>.] - ETA: 0s - loss: 0.0034 - dense_5_loss: 0.0027 - dense_6_loss: 6.7293e-04
# Epoch 5: val_loss did not improve from 0.00511
# 37789/37789 [==============================] - 2s 46us/sample - loss: 0.0034 - dense_5_loss: 0.0027 - dense_6_loss: 6.7097e-04 - val_loss: 0.0053 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 7.6496e-04
# Epoch 6/100
# 36864/37789 [============================>.] - ETA: 0s - loss: 0.0032 - dense_5_loss: 0.0025 - dense_6_loss: 6.5056e-04
# Epoch 6: val_loss improved from 0.00511 to 0.00443, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 71us/sample - loss: 0.0032 - dense_5_loss: 0.0025 - dense_6_loss: 6.4757e-04 - val_loss: 0.0044 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 6.8393e-04
# Epoch 7/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0030 - dense_5_loss: 0.0024 - dense_6_loss: 6.0963e-04
# Epoch 7: val_loss improved from 0.00443 to 0.00443, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 71us/sample - loss: 0.0030 - dense_5_loss: 0.0024 - dense_6_loss: 6.0882e-04 - val_loss: 0.0044 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 8.6298e-04
# Epoch 8/100
# 37632/37789 [============================>.] - ETA: 0s - loss: 0.0029 - dense_5_loss: 0.0023 - dense_6_loss: 5.9416e-04
# Epoch 8: val_loss did not improve from 0.00443
# 37789/37789 [==============================] - 2s 48us/sample - loss: 0.0029 - dense_5_loss: 0.0023 - dense_6_loss: 5.9476e-04 - val_loss: 0.0050 - val_dense_5_loss: 0.0042 - val_dense_6_loss: 8.1635e-04
# Epoch 9/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0027 - dense_5_loss: 0.0022 - dense_6_loss: 5.7428e-04
# Epoch 9: val_loss improved from 0.00443 to 0.00413, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 78us/sample - loss: 0.0027 - dense_5_loss: 0.0022 - dense_6_loss: 5.7504e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 6.5730e-04
# Epoch 10/100
# 36704/37789 [============================>.] - ETA: 0s - loss: 0.0028 - dense_5_loss: 0.0022 - dense_6_loss: 5.7934e-04
# Epoch 10: val_loss improved from 0.00413 to 0.00391, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 71us/sample - loss: 0.0028 - dense_5_loss: 0.0022 - dense_6_loss: 5.8251e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 4.9544e-04
# Epoch 11/100
# 37024/37789 [============================>.] - ETA: 0s - loss: 0.0027 - dense_5_loss: 0.0021 - dense_6_loss: 5.4623e-04
# Epoch 11: val_loss did not improve from 0.00391
# 37789/37789 [==============================] - 2s 48us/sample - loss: 0.0027 - dense_5_loss: 0.0021 - dense_6_loss: 5.4304e-04 - val_loss: 0.0042 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 4.6450e-04
# Epoch 12/100
# 37088/37789 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 0.0020 - dense_6_loss: 5.3140e-04
# Epoch 12: val_loss did not improve from 0.00391
# 37789/37789 [==============================] - 2s 46us/sample - loss: 0.0026 - dense_5_loss: 0.0020 - dense_6_loss: 5.3835e-04 - val_loss: 0.0052 - val_dense_5_loss: 0.0042 - val_dense_6_loss: 9.3869e-04
# Epoch 13/100
# 36864/37789 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 0.0020 - dense_6_loss: 5.6230e-04
# Epoch 13: val_loss improved from 0.00391 to 0.00388, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 84us/sample - loss: 0.0025 - dense_5_loss: 0.0020 - dense_6_loss: 5.6044e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 4.6451e-04
# Epoch 14/100
# 36896/37789 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 0.0019 - dense_6_loss: 5.4865e-04
# Epoch 14: val_loss did not improve from 0.00388
# 37789/37789 [==============================] - 2s 63us/sample - loss: 0.0025 - dense_5_loss: 0.0019 - dense_6_loss: 5.5481e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 5.7552e-04
# Epoch 15/100
# 36896/37789 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 0.0019 - dense_6_loss: 5.2968e-04
# Epoch 15: val_loss improved from 0.00388 to 0.00364, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 71us/sample - loss: 0.0024 - dense_5_loss: 0.0019 - dense_6_loss: 5.3440e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 5.9670e-04
# Epoch 16/100
# 36704/37789 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 0.0019 - dense_6_loss: 5.1322e-04
# Epoch 16: val_loss did not improve from 0.00364
# 37789/37789 [==============================] - 2s 47us/sample - loss: 0.0024 - dense_5_loss: 0.0019 - dense_6_loss: 5.0797e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 5.0195e-04
# Epoch 17/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 0.0019 - dense_6_loss: 5.4341e-04
# Epoch 17: val_loss did not improve from 0.00364
# 37789/37789 [==============================] - 2s 46us/sample - loss: 0.0024 - dense_5_loss: 0.0019 - dense_6_loss: 5.4099e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 7.2068e-04
# Epoch 18/100
# 36800/37789 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 0.0018 - dense_6_loss: 5.1408e-04
# Epoch 18: val_loss did not improve from 0.00364
# 37789/37789 [==============================] - 2s 47us/sample - loss: 0.0023 - dense_5_loss: 0.0018 - dense_6_loss: 5.1547e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 5.4068e-04
# Epoch 19/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 0.0018 - dense_6_loss: 5.0446e-04
# Epoch 19: val_loss did not improve from 0.00364
# 37789/37789 [==============================] - 2s 47us/sample - loss: 0.0023 - dense_5_loss: 0.0018 - dense_6_loss: 5.1189e-04 - val_loss: 0.0042 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 0.0010
# Epoch 20/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 0.0017 - dense_6_loss: 5.0336e-04
# Epoch 20: val_loss improved from 0.00364 to 0.00337, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 76us/sample - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.0296e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.3676e-04
# Epoch 21/100
# 37248/37789 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.0043e-04
# Epoch 21: val_loss did not improve from 0.00337
# 37789/37789 [==============================] - 2s 49us/sample - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.0142e-04 - val_loss: 0.0043 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 4.9898e-04
# Epoch 22/100
# 37789/37789 [==============================] - ETA: 0s - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.0376e-04
# Epoch 22: val_loss did not improve from 0.00337
# 37789/37789 [==============================] - 2s 45us/sample - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.0376e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 4.5303e-04
# Epoch 23/100
# 36864/37789 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 4.9826e-04
# Epoch 23: val_loss did not improve from 0.00337
# 37789/37789 [==============================] - 2s 44us/sample - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 4.9481e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 5.0405e-04
# Epoch 24/100
# 37568/37789 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.8707e-04
# Epoch 24: val_loss did not improve from 0.00337
# 37789/37789 [==============================] - 2s 46us/sample - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.8570e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 4.3553e-04
# Epoch 25/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.6685e-04
# Epoch 25: val_loss did not improve from 0.00337
# 37789/37789 [==============================] - 2s 46us/sample - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.7396e-04 - val_loss: 0.0043 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 5.8169e-04
# Epoch 26/100
# 36640/37789 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 0.0017 - dense_6_loss: 4.9280e-04
# Epoch 26: val_loss did not improve from 0.00337
# 37789/37789 [==============================] - 2s 44us/sample - loss: 0.0021 - dense_5_loss: 0.0017 - dense_6_loss: 4.8809e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.4994e-04
# Epoch 27/100
# 37664/37789 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.9732e-04
# Epoch 27: val_loss did not improve from 0.00337
# 37789/37789 [==============================] - 2s 46us/sample - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.9738e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 5.9339e-04
# Epoch 28/100
# 36736/37789 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.9254e-04
# Epoch 28: val_loss did not improve from 0.00337
# 37789/37789 [==============================] - 2s 45us/sample - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.9200e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 4.4619e-04
# Epoch 29/100
# 37408/37789 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.5754e-04
# Epoch 29: val_loss improved from 0.00337 to 0.00336, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 67us/sample - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.5649e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.4260e-04
# Epoch 30/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.4714e-04
# Epoch 30: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 45us/sample - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.4447e-04 - val_loss: 0.0045 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 5.2624e-04
# Epoch 31/100
# 37184/37789 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.5333e-04
# Epoch 31: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 45us/sample - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.5509e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 6.5416e-04
# Epoch 32/100
# 37408/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.6301e-04
# Epoch 32: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 45us/sample - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.6344e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 4.6699e-04
# Epoch 33/100
# 37632/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.3786e-04
# Epoch 33: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 46us/sample - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.3734e-04 - val_loss: 0.0045 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 0.0011
# Epoch 34/100
# 36768/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.6658e-04
# Epoch 34: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 50us/sample - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.6248e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 6.5538e-04
# Epoch 35/100
# 37696/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.6176e-04
# Epoch 35: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 51us/sample - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.6120e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 5.4285e-04
# Epoch 36/100
# 37024/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.5725e-04
# Epoch 36: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 47us/sample - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.6074e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 9.4365e-04
# Epoch 37/100
# 37152/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.4399e-04
# Epoch 37: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 48us/sample - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.3978e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 6.2711e-04
# Epoch 38/100
# 37056/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.4510e-04
# Epoch 38: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 52us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.4146e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 7.2613e-04
# Epoch 39/100
# 36672/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.3562e-04
# Epoch 39: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 51us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.3552e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0028 - val_dense_6_loss: 6.1961e-04
# Epoch 40/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.1603e-04
# Epoch 40: val_loss did not improve from 0.00336
# 37789/37789 [==============================] - 2s 52us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.1471e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 4.4594e-04
# Epoch 41/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.4304e-04
# Epoch 41: val_loss improved from 0.00336 to 0.00331, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 3s 78us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.4138e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0028 - val_dense_6_loss: 5.3905e-04
# Epoch 42/100
# 37120/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.2321e-04
# Epoch 42: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 52us/sample - loss: 0.0018 - dense_5_loss: 0.0013 - dense_6_loss: 4.2349e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 6.8820e-04
# Epoch 43/100
# 37312/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.3443e-04
# Epoch 43: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 49us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.3294e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.2634e-04
# Epoch 44/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.2866e-04
# Epoch 44: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 50us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.3016e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0027 - val_dense_6_loss: 7.1179e-04
# Epoch 45/100
# 37568/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.3026e-04
# Epoch 45: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 50us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.2935e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.6849e-04
# Epoch 46/100
# 37152/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1318e-04
# Epoch 46: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 50us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1260e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.3299e-04
# Epoch 47/100
# 37024/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.2362e-04
# Epoch 47: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 51us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.2328e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.3132e-04
# Epoch 48/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1032e-04
# Epoch 48: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 50us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1221e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 5.0036e-04
# Epoch 49/100
# 37120/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0199e-04
# Epoch 49: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 50us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 3.9839e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.6600e-04
# Epoch 50/100
# 36832/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0999e-04
# Epoch 50: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 51us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1102e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 5.0113e-04
# Epoch 51/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0735e-04
# Epoch 51: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 50us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0632e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 0.0010
# Epoch 52/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 3.9934e-04
# Epoch 52: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 52us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0203e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.3451e-04
# Epoch 53/100
# 37632/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.9632e-04
# Epoch 53: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 51us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.9544e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 4.1796e-04
# Epoch 54/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0013 - dense_6_loss: 3.8185e-04
# Epoch 54: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 47us/sample - loss: 0.0016 - dense_5_loss: 0.0013 - dense_6_loss: 3.8270e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.3464e-04
# Epoch 55/100
# 36704/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.8968e-04
# Epoch 55: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 49us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.8992e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 4.9462e-04
# Epoch 56/100
# 37152/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.7617e-04
# Epoch 56: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 48us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.7394e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 4.3224e-04
# Epoch 57/100
# 37248/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.8633e-04
# Epoch 57: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 45us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.8462e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 3.8243e-04
# Epoch 58/100
# 36672/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.8066e-04
# Epoch 58: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 45us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.8078e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 5.2909e-04
# Epoch 59/100
# 37184/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.8022e-04
# Epoch 59: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 48us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.8018e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 4.5823e-04
# Epoch 60/100
# 37696/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.6827e-04
# Epoch 60: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 47us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.6812e-04 - val_loss: 0.0047 - val_dense_5_loss: 0.0041 - val_dense_6_loss: 6.9031e-04
# Epoch 61/100
# 36864/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0012 - dense_6_loss: 3.7287e-04
# Epoch 61: val_loss did not improve from 0.00331
# 37789/37789 [==============================] - 2s 52us/sample - loss: 0.0015 - dense_5_loss: 0.0012 - dense_6_loss: 3.7231e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 4.3135e-04
# Epoch 61: early stopping
# ---Training time: 124.55791140 seconds ---

# %%
# Model Summary
print(model.summary())
plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  X_train (InputLayer)           [(None, 600)]        0           []
#
#  dense (Dense)                  (None, 128)          76928       ['X_train[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 8)            136         ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            9           ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 1)            9           ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 87,946
# Trainable params: 87,946
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)[0,] 
y_predtrain_V =np.array(y_predtrain)[1,] 

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS) 
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS)) 

train_r2_V = r2_score(Y_train_V,y_predtrain_V ) 
train_rmse_V = np.sqrt(mean_squared_error(Y_train_V, y_predtrain_V )) 

# Model Performance: Validation
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)[0,] 
y_predval_V = np.array(y_predval)[1,] 

val_r2_SS = r2_score(Y_val_SS, y_predval_SS) 
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS)) 

val_r2_V = r2_score(Y_val_V, y_predval_V) 
val_rmse_V = np.sqrt(mean_squared_error(Y_val_V, y_predval_V)) 

# Model Performance: Testing
y_predtest = model.predict([x_test])
y_predtest_SS =np.array(y_predtest)[0,] 
y_predtest_V = np.array(y_predtest)[1,] 

test_r2_SS = r2_score(y_test_SS,y_predtest_SS) 
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS)) 

test_r2_V = r2_score(y_test_V,y_predtest_V) 
test_rmse_V = np.sqrt(mean_squared_error(y_test_V, y_predtest_V)) 

# Print R2 Results 
print("R2 scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_r2_SS , train_r2_V))
print("R2 scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_r2_SS , val_r2_V))
print("R2 scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_r2_SS , test_r2_V))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_rmse_SS , train_rmse_V))
print("RMSE scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_rmse_SS , val_rmse_V))
print("RMSE scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_rmse_SS , test_rmse_V))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# R2 scores: Train (SS) - 0.96275, Train (V) - 0.91172
# R2 scores: Validation (SS) - 0.92202, Validation (V) - 0.92214
# R2 scores: Testing (SS) - 0.82732, Testing (V) - 0.82509
# RMSE scores: Train (SS) - 0.03169, Train (V) - 0.01809
# RMSE scores: Validation (SS) - 0.05546, Validation (V) - 0.02076
# RMSE scores: Testing (SS) - 0.08945, Testing (V) - 0.03567

# %%
# Inverse scaling: SS 
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# Inverse scaling: V
Y_train_V = scaler_v.inverse_transform(Y_train_V)
Y_val_V = scaler_v.inverse_transform(Y_val_V)
y_test_V = scaler_v.inverse_transform(y_test_V)
y_predtrain_V = scaler_v.inverse_transform(y_predtrain_V)
y_predval_V = scaler_v.inverse_transform(y_predval_V)
y_predtest_V = scaler_v.inverse_transform(y_predtest_V)

# %%
# Overall plot: SS & V 
ttime = df['Time'][n_steps:]
t1, testtime = train_test_split(ttime, test_size=0.2, shuffle=False)
traintime, valtime = train_test_split(t1, test_size=0.125, shuffle=False)

traintime = traintime[15200:53199] 

fig = plt.figure(1, figsize=(20,6))
plt.plot(ttime, ydf_SS)
plt.plot(traintime, y_predtrain_SS)
plt.plot(valtime, y_predval_SS)
plt.plot(testtime, y_predtest_SS)
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

fig = plt.figure(2, figsize=(20,6))
plt.plot(ttime, ydf_V)
plt.plot(traintime, y_predtrain_V)
plt.plot(valtime,  y_predval_V)
plt.plot(testtime, y_predtest_V)
plt.xlabel('Time (s)')
plt.ylabel('Slip Rate (um/s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

# %%
# # Individual plot: SS

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Shear Stress (MPa)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SS, y_predtrain_SS, 'Training data', '')
results_plot(2, valtime, Y_val_SS, y_predval_SS, 'Validation data', 'g')
results_plot(3, testtime, y_test_SS, y_predtest_SS, 'Testing data', 'r')

# %%
# # Individual plot: V

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Slip Rate (um/s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_V, y_predtrain_V, 'Training data', '')
results_plot(2, valtime, Y_val_V, y_predval_V, 'Validation data', 'g')
results_plot(3, testtime, y_test_V, y_predtest_V, 'Testing data', 'r')

# %%
# Load Libraries 
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
from keras.utils.vis_utils import plot_model
from keras.models import load_model
np.random.seed(20)   
tf.random.set_seed(20)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]  
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %% [markdown]
# **# Transfer Learning: p5271 #**

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/Data/p5271_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/Data/p5271MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel()})
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel()}) 
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(), 'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt', 'C_filt','Time','V_filt','SS']]
df_SS = df[['freqQAmpI_filt','C_filt','SS']] 
df_V = df[['freqQAmpI_filt','C_filt','V_filt']] 
df_A = df[['freqQAmpI_filt','C_filt','freqQAmpI_filt']]
df_WV = df[['freqQAmpI_filt','C_filt','C_filt']]
xdf = df[['freqQAmpI_filt', 'C_filt']]
ydf = df[['SS','V_filt']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#         freqQAmpI_filt       C_filt
# 0        86444.183014  5713.739611
# 1        86444.358094  5713.748279
# 2        86442.647757  5713.750421
# 3        86419.380962  5713.758606
# 4        86414.552286  5713.772870
# ...               ...          ...
# 75994    81488.107323  5720.364457
# 75995    81375.846782  5720.365210
# 75996    81263.154871  5720.384980
# 75997    81137.502620  5720.393775
# 75998    80982.695515  5720.397332
#
# [75999 rows x 2 columns]
# Target Data:
#               SS     V_filt
# 0      5.893849  10.577261
# 1      5.893360  10.282278
# 2      5.893242  10.050505
# 3      5.893039   9.903014
# 4      5.892528   9.945154
# ...         ...        ...
# 75994  5.850977   0.674248
# 75995  5.851531   0.653177
# 75996  5.852108   0.863880
# 75997  5.852526   0.716388
# 75998  5.852725   0.863880
#
# [75999 rows x 2 columns]

# %%
# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (V)
arr = df_V.to_numpy()
n_steps = 300
xdf, ydf_V = create_timesteps(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
n_steps = 300
xdf, ydf_A = create_timesteps(arr, n_steps)

# Preprocessing (WV)
arr = df_WV.to_numpy()
n_steps = 300
xdf, ydf_WV = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (V), Y = ', np.shape(ydf_V))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (75699, 300, 2)
# Target shape (SS), Y =  (75699,)
# Target shape (V), Y =  (75699,)
# After reshaping, X =  (75699, 600)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Split into train-val-test (V)
x_train, x_test, y_train_V, y_test_V = train_test_split(xdf, ydf_V, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_V, Y_val_V = train_test_split(x_train, y_train_V, test_size=0.125, shuffle=False)

# Select Training Data Percentage 
X_train = X_train[15200:53199]
Y_train_SS = Y_train_SS[15200:53199]
Y_train_V = Y_train_V[15200:53199]

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 37789
# Validation samples: 7570
# Testing samples: 15140

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Normalize the output: V
scaler_v = MinMaxScaler()
Y_train_V = pd.DataFrame(scaler_v.fit_transform(Y_train_V.reshape(-1, 1)))
Y_val_V = pd.DataFrame(scaler_v.transform(Y_val_V.reshape(-1, 1)))
y_test_V = pd.DataFrame(scaler_v.transform(y_test_V.reshape(-1, 1)))

# %%
# Load the pretrained model and re-fit
model = load_model('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/DD_Transfer_model_70_10_20.h5')

model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3))
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')  
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check', monitor='val_loss', verbose=1, save_best_only=True, mode='min')  #Saves best model so far
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS,Y_train_V], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS,Y_val_V]), verbose=1)
end_time = time.time()

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()

print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 37789 samples, validate on 7570 samples
# Epoch 1/100
# 37312/37789 [============================>.] - ETA: 0s - loss: 0.0118 - dense_5_loss: 0.0082 - dense_6_loss: 0.0036
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 1: val_loss improved from inf to 0.00809, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 6s 161us/sample - loss: 0.0117 - dense_5_loss: 0.0081 - dense_6_loss: 0.0036 - val_loss: 0.0081 - val_dense_5_loss: 0.0066 - val_dense_6_loss: 0.0014
# Epoch 2/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0045 - dense_5_loss: 0.0036 - dense_6_loss: 8.3194e-04
# Epoch 2: val_loss improved from 0.00809 to 0.00578, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 133us/sample - loss: 0.0044 - dense_5_loss: 0.0036 - dense_6_loss: 8.3432e-04 - val_loss: 0.0058 - val_dense_5_loss: 0.0050 - val_dense_6_loss: 8.2323e-04
# Epoch 3/100
# 37312/37789 [============================>.] - ETA: 0s - loss: 0.0037 - dense_5_loss: 0.0030 - dense_6_loss: 7.1260e-04
# Epoch 3: val_loss improved from 0.00578 to 0.00499, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 129us/sample - loss: 0.0037 - dense_5_loss: 0.0030 - dense_6_loss: 7.1127e-04 - val_loss: 0.0050 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 7.1903e-04
# Epoch 4/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0034 - dense_5_loss: 0.0027 - dense_6_loss: 6.8665e-04
# Epoch 4: val_loss did not improve from 0.00499
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0034 - dense_5_loss: 0.0027 - dense_6_loss: 6.8498e-04 - val_loss: 0.0052 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 6.5789e-04
# Epoch 5/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0032 - dense_5_loss: 0.0026 - dense_6_loss: 6.3934e-04
# Epoch 5: val_loss did not improve from 0.00499
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0032 - dense_5_loss: 0.0026 - dense_6_loss: 6.3858e-04 - val_loss: 0.0052 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 8.6345e-04
# Epoch 6/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0029 - dense_5_loss: 0.0023 - dense_6_loss: 5.9959e-04
# Epoch 6: val_loss did not improve from 0.00499
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0029 - dense_5_loss: 0.0023 - dense_6_loss: 6.0207e-04 - val_loss: 0.0061 - val_dense_5_loss: 0.0044 - val_dense_6_loss: 0.0017
# Epoch 7/100
# 37632/37789 [============================>.] - ETA: 0s - loss: 0.0028 - dense_5_loss: 0.0022 - dense_6_loss: 6.0106e-04
# Epoch 7: val_loss improved from 0.00499 to 0.00436, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 126us/sample - loss: 0.0028 - dense_5_loss: 0.0022 - dense_6_loss: 6.0007e-04 - val_loss: 0.0044 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 5.5196e-04
# Epoch 8/100
# 37248/37789 [============================>.] - ETA: 0s - loss: 0.0027 - dense_5_loss: 0.0021 - dense_6_loss: 5.7477e-04
# Epoch 8: val_loss improved from 0.00436 to 0.00392, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 124us/sample - loss: 0.0026 - dense_5_loss: 0.0021 - dense_6_loss: 5.7098e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 5.7206e-04
# Epoch 9/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0026 - dense_5_loss: 0.0020 - dense_6_loss: 5.8545e-04
# Epoch 9: val_loss improved from 0.00392 to 0.00369, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 130us/sample - loss: 0.0026 - dense_5_loss: 0.0020 - dense_6_loss: 5.8528e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 7.1682e-04
# Epoch 10/100
# 37760/37789 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 0.0019 - dense_6_loss: 5.5721e-04
# Epoch 10: val_loss did not improve from 0.00369
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0025 - dense_5_loss: 0.0019 - dense_6_loss: 5.5687e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 6.5163e-04
# Epoch 11/100
# 37789/37789 [==============================] - ETA: 0s - loss: 0.0024 - dense_5_loss: 0.0018 - dense_6_loss: 5.3616e-04
# Epoch 11: val_loss did not improve from 0.00369
# 37789/37789 [==============================] - 5s 138us/sample - loss: 0.0024 - dense_5_loss: 0.0018 - dense_6_loss: 5.3616e-04 - val_loss: 0.0044 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 7.8700e-04
# Epoch 12/100
# 37184/37789 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 0.0018 - dense_6_loss: 5.5340e-04
# Epoch 12: val_loss did not improve from 0.00369
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0024 - dense_5_loss: 0.0018 - dense_6_loss: 5.5348e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 4.4481e-04
# Epoch 13/100
# 37312/37789 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 0.0018 - dense_6_loss: 5.2470e-04
# Epoch 13: val_loss did not improve from 0.00369
# 37789/37789 [==============================] - 3s 87us/sample - loss: 0.0023 - dense_5_loss: 0.0018 - dense_6_loss: 5.2381e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 6.7292e-04
# Epoch 14/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.2217e-04
# Epoch 14: val_loss improved from 0.00369 to 0.00365, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 136us/sample - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.2384e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 6.1095e-04
# Epoch 15/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.0826e-04
# Epoch 15: val_loss did not improve from 0.00365
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.0787e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 6.0721e-04
# Epoch 16/100
# 37568/37789 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.1292e-04
# Epoch 16: val_loss did not improve from 0.00365
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.1179e-04 - val_loss: 0.0052 - val_dense_5_loss: 0.0045 - val_dense_6_loss: 6.4063e-04
# Epoch 17/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 4.9923e-04
# Epoch 17: val_loss did not improve from 0.00365
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0022 - dense_5_loss: 0.0017 - dense_6_loss: 5.0143e-04 - val_loss: 0.0044 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 0.0012
# Epoch 18/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.8456e-04
# Epoch 18: val_loss did not improve from 0.00365
# 37789/37789 [==============================] - 4s 93us/sample - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.9314e-04 - val_loss: 0.0046 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 8.0053e-04
# Epoch 19/100
# 37664/37789 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.9610e-04
# Epoch 19: val_loss did not improve from 0.00365
# 37789/37789 [==============================] - 3s 91us/sample - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.9509e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 5.1499e-04
# Epoch 20/100
# 37568/37789 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.9506e-04
# Epoch 20: val_loss did not improve from 0.00365
# 37789/37789 [==============================] - 4s 93us/sample - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 4.9357e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 4.9058e-04
# Epoch 21/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 5.0275e-04
# Epoch 21: val_loss did not improve from 0.00365
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0021 - dense_5_loss: 0.0016 - dense_6_loss: 5.0708e-04 - val_loss: 0.0044 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 0.0013
# Epoch 22/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.8185e-04
# Epoch 22: val_loss improved from 0.00365 to 0.00359, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 127us/sample - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.8192e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.3618e-04
# Epoch 23/100
# 37760/37789 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.9099e-04
# Epoch 23: val_loss did not improve from 0.00359
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.9070e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 7.9128e-04
# Epoch 24/100
# 37248/37789 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.7992e-04
# Epoch 24: val_loss did not improve from 0.00359
# 37789/37789 [==============================] - 3s 87us/sample - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.7663e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 6.7381e-04
# Epoch 25/100
# 37344/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.7901e-04
# Epoch 25: val_loss improved from 0.00359 to 0.00344, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 123us/sample - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.7701e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 5.8909e-04
# Epoch 26/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.6363e-04
# Epoch 26: val_loss did not improve from 0.00344
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.6198e-04 - val_loss: 0.0045 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 4.6277e-04
# Epoch 27/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.5705e-04
# Epoch 27: val_loss did not improve from 0.00344
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0020 - dense_5_loss: 0.0015 - dense_6_loss: 4.5493e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 5.2096e-04
# Epoch 28/100
# 37789/37789 [==============================] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.5836e-04
# Epoch 28: val_loss did not improve from 0.00344
# 37789/37789 [==============================] - 3s 87us/sample - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.5836e-04 - val_loss: 0.0044 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 6.1139e-04
# Epoch 29/100
# 37472/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.6844e-04
# Epoch 29: val_loss improved from 0.00344 to 0.00340, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 121us/sample - loss: 0.0019 - dense_5_loss: 0.0015 - dense_6_loss: 4.7101e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 4.1519e-04
# Epoch 30/100
# 37408/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.5487e-04
# Epoch 30: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 86us/sample - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.5281e-04 - val_loss: 0.0042 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 5.4828e-04
# Epoch 31/100
# 37472/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.6665e-04
# Epoch 31: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 5s 125us/sample - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.6612e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 5.0532e-04
# Epoch 32/100
# 37696/37789 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.7444e-04
# Epoch 32: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 4s 101us/sample - loss: 0.0019 - dense_5_loss: 0.0014 - dense_6_loss: 4.7358e-04 - val_loss: 0.0049 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 6.2902e-04
# Epoch 33/100
# 37216/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.2643e-04
# Epoch 33: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.2640e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.8498e-04
# Epoch 34/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.4263e-04
# Epoch 34: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.4176e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 4.6340e-04
# Epoch 35/100
# 37344/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.5585e-04
# Epoch 35: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.6359e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 7.4533e-04
# Epoch 36/100
# 37472/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.4434e-04
# Epoch 36: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 86us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.4288e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 5.6928e-04
# Epoch 37/100
# 37344/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.5633e-04
# Epoch 37: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 87us/sample - loss: 0.0018 - dense_5_loss: 0.0014 - dense_6_loss: 4.5440e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 4.6098e-04
# Epoch 38/100
# 37248/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.2929e-04
# Epoch 38: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.3007e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 8.2903e-04
# Epoch 39/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.2693e-04
# Epoch 39: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0018 - dense_5_loss: 0.0013 - dense_6_loss: 4.3301e-04 - val_loss: 0.0055 - val_dense_5_loss: 0.0041 - val_dense_6_loss: 0.0014
# Epoch 40/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 0.0013 - dense_6_loss: 4.3815e-04
# Epoch 40: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.3606e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 5.2315e-04
# Epoch 41/100
# 37344/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.2079e-04
# Epoch 41: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1891e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0028 - val_dense_6_loss: 6.2341e-04
# Epoch 42/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.3374e-04
# Epoch 42: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.3159e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 5.2715e-04
# Epoch 43/100
# 37472/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1674e-04
# Epoch 43: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1448e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 5.2714e-04
# Epoch 44/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.1031e-04
# Epoch 44: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0911e-04 - val_loss: 0.0042 - val_dense_5_loss: 0.0028 - val_dense_6_loss: 0.0014
# Epoch 45/100
# 37760/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0458e-04
# Epoch 45: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0435e-04 - val_loss: 0.0051 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 0.0011
# Epoch 46/100
# 37152/37789 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 0.0012 - dense_6_loss: 4.0484e-04
# Epoch 46: val_loss did not improve from 0.00340
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0017 - dense_5_loss: 0.0013 - dense_6_loss: 4.0606e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0027 - val_dense_6_loss: 0.0013
# Epoch 47/100
# 37568/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.1745e-04
# Epoch 47: val_loss improved from 0.00340 to 0.00328, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 130us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.1868e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0027 - val_dense_6_loss: 5.3972e-04
# Epoch 48/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.1606e-04
# Epoch 48: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 84us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.1421e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 5.9577e-04
# Epoch 49/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.1424e-04
# Epoch 49: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.1271e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 4.3069e-04
# Epoch 50/100
# 37472/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.2543e-04
# Epoch 50: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 86us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.2382e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 5.1467e-04
# Epoch 51/100
# 37408/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.9868e-04
# Epoch 51: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.9679e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 5.8893e-04
# Epoch 52/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.0803e-04
# Epoch 52: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 87us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.0640e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.2653e-04
# Epoch 53/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.2129e-04
# Epoch 53: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.2246e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 4.3897e-04
# Epoch 54/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0012 - dense_6_loss: 3.9384e-04
# Epoch 54: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.9721e-04 - val_loss: 0.0047 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 9.7776e-04
# Epoch 55/100
# 37696/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.8044e-04
# Epoch 55: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 91us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.8085e-04 - val_loss: 0.0057 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 0.0021
# Epoch 56/100
# 37664/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.9312e-04
# Epoch 56: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.9223e-04 - val_loss: 0.0051 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 5.5386e-04
# Epoch 57/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 4.1737e-04
# Epoch 57: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 91us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 4.1618e-04 - val_loss: 0.0051 - val_dense_5_loss: 0.0044 - val_dense_6_loss: 7.5733e-04
# Epoch 58/100
# 37568/37789 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 3.9749e-04
# Epoch 58: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0016 - dense_5_loss: 0.0012 - dense_6_loss: 4.0093e-04 - val_loss: 0.0046 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 6.8371e-04
# Epoch 59/100
# 37312/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.9697e-04
# Epoch 59: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 91us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.9489e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 4.3876e-04
# Epoch 60/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.8040e-04
# Epoch 60: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 4s 94us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.7901e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 4.6907e-04
# Epoch 61/100
# 37760/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.9460e-04
# Epoch 61: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 91us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.9459e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 3.9278e-04
# Epoch 62/100
# 37568/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 4.0013e-04
# Epoch 62: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 4s 104us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.9941e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 4.4551e-04
# Epoch 63/100
# 37789/37789 [==============================] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.7598e-04
# Epoch 63: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 5s 122us/sample - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.7598e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 4.3216e-04
# Epoch 64/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.8530e-04
# Epoch 64: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.8551e-04 - val_loss: 0.0035 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 5.1459e-04
# Epoch 65/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.8550e-04
# Epoch 65: val_loss did not improve from 0.00328
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.8557e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 5.2466e-04
# Epoch 66/100
# 37312/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.7594e-04
# Epoch 66: val_loss improved from 0.00328 to 0.00317, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 126us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.7713e-04 - val_loss: 0.0032 - val_dense_5_loss: 0.0027 - val_dense_6_loss: 4.3172e-04
# Epoch 67/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.7175e-04
# Epoch 67: val_loss did not improve from 0.00317
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.7072e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.5346e-04
# Epoch 68/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.9321e-04
# Epoch 68: val_loss did not improve from 0.00317
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0015 - dense_5_loss: 0.0011 - dense_6_loss: 3.9238e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 4.6495e-04
# Epoch 69/100
# 37344/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.4877e-04
# Epoch 69: val_loss did not improve from 0.00317
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.4732e-04 - val_loss: 0.0042 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 5.1948e-04
# Epoch 70/100
# 37664/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.6478e-04
# Epoch 70: val_loss did not improve from 0.00317
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.6428e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.2018e-04
# Epoch 71/100
# 37248/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.5607e-04
# Epoch 71: val_loss did not improve from 0.00317
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.5470e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 5.5057e-04
# Epoch 72/100
# 37789/37789 [==============================] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.7626e-04
# Epoch 72: val_loss did not improve from 0.00317
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.7626e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 4.7519e-04
# Epoch 73/100
# 37184/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.5068e-04
# Epoch 73: val_loss did not improve from 0.00317
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.5255e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.4767e-04
# Epoch 74/100
# 37472/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 9.9850e-04 - dense_6_loss: 3.6561e-04
# Epoch 74: val_loss improved from 0.00317 to 0.00308, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 124us/sample - loss: 0.0014 - dense_5_loss: 9.9980e-04 - dense_6_loss: 3.6659e-04 - val_loss: 0.0031 - val_dense_5_loss: 0.0027 - val_dense_6_loss: 3.9038e-04
# Epoch 75/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.5873e-04
# Epoch 75: val_loss did not improve from 0.00308
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.5804e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0033 - val_dense_6_loss: 5.5605e-04
# Epoch 76/100
# 37120/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.5595e-04
# Epoch 76: val_loss did not improve from 0.00308
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.5490e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 3.9922e-04
# Epoch 77/100
# 37312/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.7669e-04 - dense_6_loss: 3.6755e-04
# Epoch 77: val_loss did not improve from 0.00308
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0013 - dense_5_loss: 9.7569e-04 - dense_6_loss: 3.6961e-04 - val_loss: 0.0056 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 0.0010
# Epoch 78/100
# 37344/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.9081e-04 - dense_6_loss: 3.5353e-04
# Epoch 78: val_loss did not improve from 0.00308
# 37789/37789 [==============================] - 4s 93us/sample - loss: 0.0014 - dense_5_loss: 9.9763e-04 - dense_6_loss: 3.5493e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0026 - val_dense_6_loss: 6.7267e-04
# Epoch 79/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.5454e-04
# Epoch 79: val_loss did not improve from 0.00308
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.5631e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 9.8079e-04
# Epoch 80/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.9331e-04
# Epoch 80: val_loss did not improve from 0.00308
# 37789/37789 [==============================] - 3s 91us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.9226e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 5.5965e-04
# Epoch 81/100
# 37760/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.7145e-04 - dense_6_loss: 3.5128e-04
# Epoch 81: val_loss did not improve from 0.00308
# 37789/37789 [==============================] - 3s 92us/sample - loss: 0.0013 - dense_5_loss: 9.7116e-04 - dense_6_loss: 3.5125e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 5.0244e-04
# Epoch 82/100
# 37408/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 9.9482e-04 - dense_6_loss: 3.7066e-04
# Epoch 82: val_loss improved from 0.00308 to 0.00294, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Transfer_Learning_p5271/TL_Data_Driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 37789/37789 [==============================] - 5s 130us/sample - loss: 0.0014 - dense_5_loss: 9.9338e-04 - dense_6_loss: 3.7127e-04 - val_loss: 0.0029 - val_dense_5_loss: 0.0025 - val_dense_6_loss: 4.5146e-04
# Epoch 83/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 9.9186e-04 - dense_6_loss: 3.6890e-04
# Epoch 83: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0014 - dense_5_loss: 9.8946e-04 - dense_6_loss: 3.6814e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 4.9830e-04
# Epoch 84/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.6972e-04 - dense_6_loss: 3.5228e-04
# Epoch 84: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0013 - dense_5_loss: 9.7056e-04 - dense_6_loss: 3.5205e-04 - val_loss: 0.0042 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 4.7025e-04
# Epoch 85/100
# 37789/37789 [==============================] - ETA: 0s - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.6754e-04
# Epoch 85: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 91us/sample - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.6754e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0027 - val_dense_6_loss: 5.2579e-04
# Epoch 86/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0014 - dense_5_loss: 9.9114e-04 - dense_6_loss: 3.6341e-04
# Epoch 86: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 4s 95us/sample - loss: 0.0014 - dense_5_loss: 9.9117e-04 - dense_6_loss: 3.6451e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 4.4164e-04
# Epoch 87/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.2048e-04 - dense_6_loss: 3.3661e-04
# Epoch 87: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0013 - dense_5_loss: 9.1982e-04 - dense_6_loss: 3.4002e-04 - val_loss: 0.0040 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 0.0010
# Epoch 88/100
# 37664/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.4895e-04 - dense_6_loss: 3.5347e-04
# Epoch 88: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 90us/sample - loss: 0.0013 - dense_5_loss: 9.5069e-04 - dense_6_loss: 3.5422e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0028 - val_dense_6_loss: 7.9229e-04
# Epoch 89/100
# 37664/37789 [============================>.] - ETA: 0s - loss: 0.0012 - dense_5_loss: 9.2476e-04 - dense_6_loss: 3.2505e-04
# Epoch 89: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0013 - dense_5_loss: 9.2518e-04 - dense_6_loss: 3.2516e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 6.2823e-04
# Epoch 90/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.4167e-04 - dense_6_loss: 3.7205e-04
# Epoch 90: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0013 - dense_5_loss: 9.4328e-04 - dense_6_loss: 3.7399e-04 - val_loss: 0.0041 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 9.1310e-04
# Epoch 91/100
# 37696/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.9571e-04 - dense_6_loss: 3.4573e-04
# Epoch 91: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 87us/sample - loss: 0.0013 - dense_5_loss: 9.9466e-04 - dense_6_loss: 3.4510e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.2042e-04
# Epoch 92/100
# 37440/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.2941e-04 - dense_6_loss: 3.4637e-04
# Epoch 92: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0013 - dense_5_loss: 9.2763e-04 - dense_6_loss: 3.4428e-04 - val_loss: 0.0039 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 4.6828e-04
# Epoch 93/100
# 37504/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.7043e-04 - dense_6_loss: 3.5775e-04
# Epoch 93: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 5s 134us/sample - loss: 0.0013 - dense_5_loss: 9.6986e-04 - dense_6_loss: 3.5559e-04 - val_loss: 0.0032 - val_dense_5_loss: 0.0027 - val_dense_6_loss: 4.7179e-04
# Epoch 94/100
# 37280/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.4741e-04 - dense_6_loss: 3.4319e-04
# Epoch 94: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 4s 93us/sample - loss: 0.0013 - dense_5_loss: 9.5256e-04 - dense_6_loss: 3.4593e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.5355e-04
# Epoch 95/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.5594e-04 - dense_6_loss: 3.2796e-04
# Epoch 95: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 88us/sample - loss: 0.0013 - dense_5_loss: 9.5614e-04 - dense_6_loss: 3.2766e-04 - val_loss: 0.0037 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 5.5082e-04
# Epoch 96/100
# 37600/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.5610e-04 - dense_6_loss: 3.5098e-04
# Epoch 96: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0013 - dense_5_loss: 9.5892e-04 - dense_6_loss: 3.5006e-04 - val_loss: 0.0036 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 4.4866e-04
# Epoch 97/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.5213e-04 - dense_6_loss: 3.4994e-04
# Epoch 97: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 87us/sample - loss: 0.0013 - dense_5_loss: 9.5303e-04 - dense_6_loss: 3.4854e-04 - val_loss: 0.0038 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 5.6528e-04
# Epoch 98/100
# 37376/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.1464e-04 - dense_6_loss: 3.4071e-04
# Epoch 98: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 89us/sample - loss: 0.0013 - dense_5_loss: 9.1401e-04 - dense_6_loss: 3.3994e-04 - val_loss: 0.0031 - val_dense_5_loss: 0.0027 - val_dense_6_loss: 4.3675e-04
# Epoch 99/100
# 37536/37789 [============================>.] - ETA: 0s - loss: 0.0012 - dense_5_loss: 8.9143e-04 - dense_6_loss: 3.3836e-04
# Epoch 99: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 87us/sample - loss: 0.0012 - dense_5_loss: 8.9181e-04 - dense_6_loss: 3.3711e-04 - val_loss: 0.0042 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 5.7682e-04
# Epoch 100/100
# 37472/37789 [============================>.] - ETA: 0s - loss: 0.0013 - dense_5_loss: 9.3137e-04 - dense_6_loss: 3.3615e-04
# Epoch 100: val_loss did not improve from 0.00294
# 37789/37789 [==============================] - 3s 91us/sample - loss: 0.0013 - dense_5_loss: 9.3058e-04 - dense_6_loss: 3.3908e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 4.9779e-04
# ---Training time: 368.12762475 seconds ---

# %%
# Model Summary
print(model.summary())
plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  X_train (InputLayer)           [(None, 600)]        0           []
#
#  dense (Dense)                  (None, 128)          76928       ['X_train[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 8)            136         ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            9           ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 1)            9           ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 87,946
# Trainable params: 87,946
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)[0,] 
y_predtrain_V =np.array(y_predtrain)[1,] 

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS) 
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS)) 

train_r2_V = r2_score(Y_train_V,y_predtrain_V ) 
train_rmse_V = np.sqrt(mean_squared_error(Y_train_V, y_predtrain_V )) 

# Model Performance: Validation
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)[0,] 
y_predval_V = np.array(y_predval)[1,] 

val_r2_SS = r2_score(Y_val_SS, y_predval_SS) 
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS)) 

val_r2_V = r2_score(Y_val_V, y_predval_V) 
val_rmse_V = np.sqrt(mean_squared_error(Y_val_V, y_predval_V)) 

# Model Performance: Testing
y_predtest = model.predict([x_test])
y_predtest_SS =np.array(y_predtest)[0,] 
y_predtest_V = np.array(y_predtest)[1,] 

test_r2_SS = r2_score(y_test_SS,y_predtest_SS) 
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS)) 

test_r2_V = r2_score(y_test_V,y_predtest_V) 
test_rmse_V = np.sqrt(mean_squared_error(y_test_V, y_predtest_V)) 

# Print R2 Results 
print("R2 scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_r2_SS , train_r2_V))
print("R2 scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_r2_SS , val_r2_V))
print("R2 scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_r2_SS , test_r2_V))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_rmse_SS , train_rmse_V))
print("RMSE scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_rmse_SS , val_rmse_V))
print("RMSE scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_rmse_SS , test_rmse_V))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# R2 scores: Train (SS) - 0.97020, Train (V) - 0.91623
# R2 scores: Validation (SS) - 0.92720, Validation (V) - 0.90992
# R2 scores: Testing (SS) - 0.79654, Testing (V) - 0.71851
# RMSE scores: Train (SS) - 0.02835, Train (V) - 0.01763
# RMSE scores: Validation (SS) - 0.05358, Validation (V) - 0.02233
# RMSE scores: Testing (SS) - 0.09709, Testing (V) - 0.04525

# %%
# Inverse scaling: SS 
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# Inverse scaling: V
Y_train_V = scaler_v.inverse_transform(Y_train_V)
Y_val_V = scaler_v.inverse_transform(Y_val_V)
y_test_V = scaler_v.inverse_transform(y_test_V)
y_predtrain_V = scaler_v.inverse_transform(y_predtrain_V)
y_predval_V = scaler_v.inverse_transform(y_predval_V)
y_predtest_V = scaler_v.inverse_transform(y_predtest_V)

# %%
# Overall plot: SS & V 
ttime = df['Time'][n_steps:]
t1, testtime = train_test_split(ttime, test_size=0.2, shuffle=False)
traintime, valtime = train_test_split(t1, test_size=0.125, shuffle=False)

traintime = traintime[15200:53199] 

fig = plt.figure(1, figsize=(20,6))
plt.plot(ttime, ydf_SS)
plt.plot(traintime, y_predtrain_SS)
plt.plot(valtime, y_predval_SS)
plt.plot(testtime, y_predtest_SS)
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

fig = plt.figure(2, figsize=(20,6))
plt.plot(ttime, ydf_V)
plt.plot(traintime, y_predtrain_V)
plt.plot(valtime,  y_predval_V)
plt.plot(testtime, y_predtest_V)
plt.xlabel('Time (s)')
plt.ylabel('Slip Rate (um/s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

# %%
# # Individual plot: SS

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Shear Stress (MPa)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SS, y_predtrain_SS, 'Training data', '')
results_plot(2, valtime, Y_val_SS, y_predval_SS, 'Validation data', 'g')
results_plot(3, testtime, y_test_SS, y_predtest_SS, 'Testing data', 'r')

# %%
# # Individual plot: V

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Slip Rate (um/s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_V, y_predtrain_V, 'Training data', '')
results_plot(2, valtime, Y_val_V, y_predval_V, 'Validation data', 'g')
results_plot(3, testtime, y_test_V, y_predtest_V, 'Testing data', 'r')

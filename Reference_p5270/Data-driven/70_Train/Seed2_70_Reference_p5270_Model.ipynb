# %%
# Load Libraries 
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
from keras.utils.vis_utils import plot_model
np.random.seed(10)   
tf.random.set_seed(10)

# %%
# Mount Google Drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1] 
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel()})
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel()}) 
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(),'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt', 'C_filt','Time','V_filt','SS']]
df_SS = df[['freqQAmpI_filt','C_filt','SS']] 
df_V = df[['freqQAmpI_filt','C_filt','V_filt']] 
df_A = df[['freqQAmpI_filt','C_filt','freqQAmpI_filt']]
df_WV = df[['freqQAmpI_filt','C_filt','C_filt']]
xdf = df[['freqQAmpI_filt', 'C_filt']]
ydf = df[['SS','V_filt']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#          freqQAmpI_filt       C_filt
# 0         31453.223522  5490.232850
# 1         31438.277060  5490.239343
# 2         31421.341616  5490.240838
# 3         31409.798761  5490.232728
# 4         31398.815589  5490.222463
# ...                ...          ...
# 132394    31055.686766  5457.051859
# 132395    31041.955345  5457.082380
# 132396    31035.059531  5457.111463
# 132397    31020.001291  5457.126443
# 132398    31012.016780  5457.151945
#
# [132399 rows x 2 columns]
# Target Data:
#                SS    V_filt
# 0       5.656166  1.201004
# 1       5.657157  1.243144
# 2       5.658317  1.264215
# 3       5.659499  1.243144
# 4       5.660404  1.222074
# ...          ...       ...
# 132394  5.471059  1.285285
# 132395  5.474545  0.948161
# 132396  5.478286  1.158863
# 132397  5.481751  1.201004
# 132398  5.484813  0.526756
#
# [132399 rows x 2 columns]

# %%
# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (V)
arr = df_V.to_numpy()
n_steps = 300
xdf, ydf_V = create_timesteps(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
n_steps = 300
xdf, ydf_A = create_timesteps(arr, n_steps)

# Preprocessing (WV)
arr = df_WV.to_numpy()
n_steps = 300
xdf, ydf_WV = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (V), Y = ', np.shape(ydf_V))

# Reshape 
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132099, 300, 2)
# Target shape (SS), Y =  (132099,)
# Target shape (V), Y =  (132099,)
# After reshaping, X =  (132099, 600)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Split into train-val-test (V)
x_train, x_test, y_train_V, y_test_V = train_test_split(xdf, ydf_V, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_V, Y_val_V = train_test_split(x_train, y_train_V, test_size=0.125, shuffle=False)

# Select Train
X_train = X_train[0:92469] 
Y_train_SS = Y_train_SS[0:92469]
Y_train_V = Y_train_V[0:92469]

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 92469
# Validation samples: 13210
# Testing samples: 26420

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Normalize the output: V
scaler_v = MinMaxScaler()
Y_train_V = pd.DataFrame(scaler_v.fit_transform(Y_train_V.reshape(-1, 1)))
Y_val_V = pd.DataFrame(scaler_v.transform(Y_val_V.reshape(-1, 1)))
y_test_V = pd.DataFrame(scaler_v.transform(y_test_V.reshape(-1, 1)))

# %% [markdown]
# **Define Data-Driven Model**

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(600),name='X_train')    

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)
  v_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred,v_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  X_train (InputLayer)           [(None, 600)]        0           []
#
#  dense (Dense)                  (None, 128)          76928       ['X_train[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 8)            136         ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            9           ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 1)            9           ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 87,946
# Trainable params: 87,946
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')  
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check', monitor='val_loss', verbose=1, save_best_only=True, mode='min')  
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS,Y_train_V], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS,Y_val_V]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 92469 samples, validate on 13210 samples
# Epoch 1/100
# 91904/92469 [============================>.] - ETA: 0s - loss: 0.0261 - dense_5_loss: 0.0163 - dense_6_loss: 0.0098 - dense_5_mse: 0.0163 - dense_6_mse: 0.0098
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2045: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 1: val_loss improved from inf to 0.01863, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 14s 154us/sample - loss: 0.0260 - dense_5_loss: 0.0163 - dense_6_loss: 0.0097 - dense_5_mse: 0.0163 - dense_6_mse: 0.0097 - val_loss: 0.0186 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 0.0147 - val_dense_5_mse: 0.0039 - val_dense_6_mse: 0.0147
# Epoch 2/100
# 91968/92469 [============================>.] - ETA: 0s - loss: 0.0116 - dense_5_loss: 0.0036 - dense_6_loss: 0.0080 - dense_5_mse: 0.0036 - dense_6_mse: 0.0080
# Epoch 2: val_loss improved from 0.01863 to 0.01388, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 10s 108us/sample - loss: 0.0116 - dense_5_loss: 0.0036 - dense_6_loss: 0.0080 - dense_5_mse: 0.0036 - dense_6_mse: 0.0080 - val_loss: 0.0139 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 0.0107 - val_dense_5_mse: 0.0032 - val_dense_6_mse: 0.0107
# Epoch 3/100
# 92032/92469 [============================>.] - ETA: 0s - loss: 0.0093 - dense_5_loss: 0.0032 - dense_6_loss: 0.0061 - dense_5_mse: 0.0032 - dense_6_mse: 0.0061
# Epoch 3: val_loss improved from 0.01388 to 0.01341, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 10s 111us/sample - loss: 0.0093 - dense_5_loss: 0.0032 - dense_6_loss: 0.0061 - dense_5_mse: 0.0032 - dense_6_mse: 0.0061 - val_loss: 0.0134 - val_dense_5_loss: 0.0022 - val_dense_6_loss: 0.0113 - val_dense_5_mse: 0.0022 - val_dense_6_mse: 0.0113
# Epoch 4/100
# 92064/92469 [============================>.] - ETA: 0s - loss: 0.0073 - dense_5_loss: 0.0028 - dense_6_loss: 0.0045 - dense_5_mse: 0.0028 - dense_6_mse: 0.0045
# Epoch 4: val_loss improved from 0.01341 to 0.00966, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 10s 113us/sample - loss: 0.0073 - dense_5_loss: 0.0028 - dense_6_loss: 0.0045 - dense_5_mse: 0.0028 - dense_6_mse: 0.0045 - val_loss: 0.0097 - val_dense_5_loss: 0.0023 - val_dense_6_loss: 0.0074 - val_dense_5_mse: 0.0023 - val_dense_6_mse: 0.0074
# Epoch 5/100
# 92000/92469 [============================>.] - ETA: 0s - loss: 0.0070 - dense_5_loss: 0.0026 - dense_6_loss: 0.0043 - dense_5_mse: 0.0026 - dense_6_mse: 0.0043
# Epoch 5: val_loss improved from 0.00966 to 0.00641, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 11s 117us/sample - loss: 0.0070 - dense_5_loss: 0.0026 - dense_6_loss: 0.0043 - dense_5_mse: 0.0026 - dense_6_mse: 0.0043 - val_loss: 0.0064 - val_dense_5_loss: 0.0024 - val_dense_6_loss: 0.0040 - val_dense_5_mse: 0.0024 - val_dense_6_mse: 0.0040
# Epoch 6/100
# 92352/92469 [============================>.] - ETA: 0s - loss: 0.0062 - dense_5_loss: 0.0025 - dense_6_loss: 0.0037 - dense_5_mse: 0.0025 - dense_6_mse: 0.0037
# Epoch 6: val_loss did not improve from 0.00641
# 92469/92469 [==============================] - 9s 99us/sample - loss: 0.0062 - dense_5_loss: 0.0025 - dense_6_loss: 0.0037 - dense_5_mse: 0.0025 - dense_6_mse: 0.0037 - val_loss: 0.0122 - val_dense_5_loss: 0.0021 - val_dense_6_loss: 0.0101 - val_dense_5_mse: 0.0021 - val_dense_6_mse: 0.0101
# Epoch 7/100
# 92096/92469 [============================>.] - ETA: 0s - loss: 0.0056 - dense_5_loss: 0.0023 - dense_6_loss: 0.0034 - dense_5_mse: 0.0023 - dense_6_mse: 0.0034
# Epoch 7: val_loss improved from 0.00641 to 0.00386, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 14s 149us/sample - loss: 0.0056 - dense_5_loss: 0.0023 - dense_6_loss: 0.0034 - dense_5_mse: 0.0023 - dense_6_mse: 0.0034 - val_loss: 0.0039 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0025 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0025
# Epoch 8/100
# 92096/92469 [============================>.] - ETA: 0s - loss: 0.0051 - dense_5_loss: 0.0021 - dense_6_loss: 0.0030 - dense_5_mse: 0.0021 - dense_6_mse: 0.0030
# Epoch 8: val_loss did not improve from 0.00386
# 92469/92469 [==============================] - 9s 95us/sample - loss: 0.0051 - dense_5_loss: 0.0021 - dense_6_loss: 0.0030 - dense_5_mse: 0.0021 - dense_6_mse: 0.0030 - val_loss: 0.0048 - val_dense_5_loss: 0.0017 - val_dense_6_loss: 0.0030 - val_dense_5_mse: 0.0017 - val_dense_6_mse: 0.0030
# Epoch 9/100
# 92352/92469 [============================>.] - ETA: 0s - loss: 0.0062 - dense_5_loss: 0.0024 - dense_6_loss: 0.0038 - dense_5_mse: 0.0024 - dense_6_mse: 0.0038
# Epoch 9: val_loss did not improve from 0.00386
# 92469/92469 [==============================] - 11s 119us/sample - loss: 0.0062 - dense_5_loss: 0.0024 - dense_6_loss: 0.0038 - dense_5_mse: 0.0024 - dense_6_mse: 0.0038 - val_loss: 0.0045 - val_dense_5_loss: 0.0016 - val_dense_6_loss: 0.0029 - val_dense_5_mse: 0.0016 - val_dense_6_mse: 0.0029
# Epoch 10/100
# 92320/92469 [============================>.] - ETA: 0s - loss: 0.0050 - dense_5_loss: 0.0020 - dense_6_loss: 0.0030 - dense_5_mse: 0.0020 - dense_6_mse: 0.0030
# Epoch 10: val_loss did not improve from 0.00386
# 92469/92469 [==============================] - 9s 96us/sample - loss: 0.0050 - dense_5_loss: 0.0020 - dense_6_loss: 0.0030 - dense_5_mse: 0.0020 - dense_6_mse: 0.0030 - val_loss: 0.0141 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 0.0102 - val_dense_5_mse: 0.0039 - val_dense_6_mse: 0.0102
# Epoch 11/100
# 92352/92469 [============================>.] - ETA: 0s - loss: 0.0050 - dense_5_loss: 0.0020 - dense_6_loss: 0.0031 - dense_5_mse: 0.0020 - dense_6_mse: 0.0031
# Epoch 11: val_loss did not improve from 0.00386
# 92469/92469 [==============================] - 12s 126us/sample - loss: 0.0050 - dense_5_loss: 0.0020 - dense_6_loss: 0.0031 - dense_5_mse: 0.0020 - dense_6_mse: 0.0031 - val_loss: 0.0060 - val_dense_5_loss: 0.0024 - val_dense_6_loss: 0.0036 - val_dense_5_mse: 0.0024 - val_dense_6_mse: 0.0036
# Epoch 12/100
# 92256/92469 [============================>.] - ETA: 0s - loss: 0.0048 - dense_5_loss: 0.0019 - dense_6_loss: 0.0029 - dense_5_mse: 0.0019 - dense_6_mse: 0.0029
# Epoch 12: val_loss improved from 0.00386 to 0.00311, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 11s 116us/sample - loss: 0.0048 - dense_5_loss: 0.0019 - dense_6_loss: 0.0029 - dense_5_mse: 0.0019 - dense_6_mse: 0.0029 - val_loss: 0.0031 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0019 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0019
# Epoch 13/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0048 - dense_5_loss: 0.0018 - dense_6_loss: 0.0029 - dense_5_mse: 0.0018 - dense_6_mse: 0.0029
# Epoch 13: val_loss did not improve from 0.00311
# 92469/92469 [==============================] - 12s 127us/sample - loss: 0.0048 - dense_5_loss: 0.0018 - dense_6_loss: 0.0029 - dense_5_mse: 0.0018 - dense_6_mse: 0.0029 - val_loss: 0.0040 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0026 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0026
# Epoch 14/100
# 92096/92469 [============================>.] - ETA: 0s - loss: 0.0044 - dense_5_loss: 0.0017 - dense_6_loss: 0.0027 - dense_5_mse: 0.0017 - dense_6_mse: 0.0027
# Epoch 14: val_loss did not improve from 0.00311
# 92469/92469 [==============================] - 10s 104us/sample - loss: 0.0044 - dense_5_loss: 0.0017 - dense_6_loss: 0.0027 - dense_5_mse: 0.0017 - dense_6_mse: 0.0027 - val_loss: 0.0033 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0022 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0022
# Epoch 15/100
# 92192/92469 [============================>.] - ETA: 0s - loss: 0.0043 - dense_5_loss: 0.0017 - dense_6_loss: 0.0026 - dense_5_mse: 0.0017 - dense_6_mse: 0.0026
# Epoch 15: val_loss did not improve from 0.00311
# 92469/92469 [==============================] - 12s 126us/sample - loss: 0.0043 - dense_5_loss: 0.0017 - dense_6_loss: 0.0026 - dense_5_mse: 0.0017 - dense_6_mse: 0.0026 - val_loss: 0.0044 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0031 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0031
# Epoch 16/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0039 - dense_5_loss: 0.0016 - dense_6_loss: 0.0023 - dense_5_mse: 0.0016 - dense_6_mse: 0.0023
# Epoch 16: val_loss did not improve from 0.00311
# 92469/92469 [==============================] - 9s 100us/sample - loss: 0.0039 - dense_5_loss: 0.0016 - dense_6_loss: 0.0023 - dense_5_mse: 0.0016 - dense_6_mse: 0.0023 - val_loss: 0.0035 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0024 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0024
# Epoch 17/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0041 - dense_5_loss: 0.0016 - dense_6_loss: 0.0025 - dense_5_mse: 0.0016 - dense_6_mse: 0.0025
# Epoch 17: val_loss did not improve from 0.00311
# 92469/92469 [==============================] - 12s 127us/sample - loss: 0.0041 - dense_5_loss: 0.0016 - dense_6_loss: 0.0025 - dense_5_mse: 0.0016 - dense_6_mse: 0.0025 - val_loss: 0.0045 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0032 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0032
# Epoch 18/100
# 92032/92469 [============================>.] - ETA: 0s - loss: 0.0037 - dense_5_loss: 0.0014 - dense_6_loss: 0.0022 - dense_5_mse: 0.0014 - dense_6_mse: 0.0022
# Epoch 18: val_loss did not improve from 0.00311
# 92469/92469 [==============================] - 9s 98us/sample - loss: 0.0037 - dense_5_loss: 0.0014 - dense_6_loss: 0.0023 - dense_5_mse: 0.0014 - dense_6_mse: 0.0023 - val_loss: 0.0041 - val_dense_5_loss: 0.0017 - val_dense_6_loss: 0.0023 - val_dense_5_mse: 0.0017 - val_dense_6_mse: 0.0023
# Epoch 19/100
# 92096/92469 [============================>.] - ETA: 0s - loss: 0.0040 - dense_5_loss: 0.0016 - dense_6_loss: 0.0025 - dense_5_mse: 0.0016 - dense_6_mse: 0.0025
# Epoch 19: val_loss did not improve from 0.00311
# 92469/92469 [==============================] - 12s 129us/sample - loss: 0.0040 - dense_5_loss: 0.0016 - dense_6_loss: 0.0025 - dense_5_mse: 0.0016 - dense_6_mse: 0.0025 - val_loss: 0.0036 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0024 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0024
# Epoch 20/100
# 92192/92469 [============================>.] - ETA: 0s - loss: 0.0035 - dense_5_loss: 0.0013 - dense_6_loss: 0.0022 - dense_5_mse: 0.0013 - dense_6_mse: 0.0022
# Epoch 20: val_loss improved from 0.00311 to 0.00269, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 11s 120us/sample - loss: 0.0035 - dense_5_loss: 0.0013 - dense_6_loss: 0.0022 - dense_5_mse: 0.0013 - dense_6_mse: 0.0022 - val_loss: 0.0027 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0016 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0016
# Epoch 21/100
# 92064/92469 [============================>.] - ETA: 0s - loss: 0.0035 - dense_5_loss: 0.0013 - dense_6_loss: 0.0022 - dense_5_mse: 0.0013 - dense_6_mse: 0.0022
# Epoch 21: val_loss did not improve from 0.00269
# 92469/92469 [==============================] - 11s 123us/sample - loss: 0.0035 - dense_5_loss: 0.0013 - dense_6_loss: 0.0022 - dense_5_mse: 0.0013 - dense_6_mse: 0.0022 - val_loss: 0.0045 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0032 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0032
# Epoch 22/100
# 92384/92469 [============================>.] - ETA: 0s - loss: 0.0034 - dense_5_loss: 0.0013 - dense_6_loss: 0.0021 - dense_5_mse: 0.0013 - dense_6_mse: 0.0021
# Epoch 22: val_loss did not improve from 0.00269
# 92469/92469 [==============================] - 10s 103us/sample - loss: 0.0034 - dense_5_loss: 0.0013 - dense_6_loss: 0.0021 - dense_5_mse: 0.0013 - dense_6_mse: 0.0021 - val_loss: 0.0036 - val_dense_5_loss: 0.0016 - val_dense_6_loss: 0.0021 - val_dense_5_mse: 0.0016 - val_dense_6_mse: 0.0021
# Epoch 23/100
# 92288/92469 [============================>.] - ETA: 0s - loss: 0.0030 - dense_5_loss: 0.0012 - dense_6_loss: 0.0019 - dense_5_mse: 0.0012 - dense_6_mse: 0.0019
# Epoch 23: val_loss did not improve from 0.00269
# 92469/92469 [==============================] - 13s 140us/sample - loss: 0.0030 - dense_5_loss: 0.0012 - dense_6_loss: 0.0019 - dense_5_mse: 0.0012 - dense_6_mse: 0.0019 - val_loss: 0.0041 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0027 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0027
# Epoch 24/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0032 - dense_5_loss: 0.0013 - dense_6_loss: 0.0020 - dense_5_mse: 0.0013 - dense_6_mse: 0.0020
# Epoch 24: val_loss did not improve from 0.00269
# 92469/92469 [==============================] - 9s 98us/sample - loss: 0.0032 - dense_5_loss: 0.0013 - dense_6_loss: 0.0020 - dense_5_mse: 0.0013 - dense_6_mse: 0.0020 - val_loss: 0.0027 - val_dense_5_loss: 9.7614e-04 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 9.7618e-04 - val_dense_6_mse: 0.0018
# Epoch 25/100
# 92288/92469 [============================>.] - ETA: 0s - loss: 0.0031 - dense_5_loss: 0.0012 - dense_6_loss: 0.0019 - dense_5_mse: 0.0012 - dense_6_mse: 0.0019
# Epoch 25: val_loss did not improve from 0.00269
# 92469/92469 [==============================] - 12s 127us/sample - loss: 0.0031 - dense_5_loss: 0.0012 - dense_6_loss: 0.0019 - dense_5_mse: 0.0012 - dense_6_mse: 0.0019 - val_loss: 0.0036 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0023 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0023
# Epoch 26/100
# 92288/92469 [============================>.] - ETA: 0s - loss: 0.0032 - dense_5_loss: 0.0012 - dense_6_loss: 0.0020 - dense_5_mse: 0.0012 - dense_6_mse: 0.0020
# Epoch 26: val_loss improved from 0.00269 to 0.00252, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 10s 112us/sample - loss: 0.0032 - dense_5_loss: 0.0012 - dense_6_loss: 0.0020 - dense_5_mse: 0.0012 - dense_6_mse: 0.0020 - val_loss: 0.0025 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0014
# Epoch 27/100
# 92448/92469 [============================>.] - ETA: 0s - loss: 0.0029 - dense_5_loss: 0.0011 - dense_6_loss: 0.0018 - dense_5_mse: 0.0011 - dense_6_mse: 0.0018
# Epoch 27: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 12s 128us/sample - loss: 0.0029 - dense_5_loss: 0.0011 - dense_6_loss: 0.0018 - dense_5_mse: 0.0011 - dense_6_mse: 0.0018 - val_loss: 0.0034 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0021 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0021
# Epoch 28/100
# 91840/92469 [============================>.] - ETA: 0s - loss: 0.0030 - dense_5_loss: 0.0011 - dense_6_loss: 0.0019 - dense_5_mse: 0.0011 - dense_6_mse: 0.0019
# Epoch 28: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 9s 97us/sample - loss: 0.0031 - dense_5_loss: 0.0012 - dense_6_loss: 0.0019 - dense_5_mse: 0.0012 - dense_6_mse: 0.0019 - val_loss: 0.0089 - val_dense_5_loss: 0.0016 - val_dense_6_loss: 0.0074 - val_dense_5_mse: 0.0016 - val_dense_6_mse: 0.0074
# Epoch 29/100
# 92352/92469 [============================>.] - ETA: 0s - loss: 0.0032 - dense_5_loss: 0.0013 - dense_6_loss: 0.0019 - dense_5_mse: 0.0013 - dense_6_mse: 0.0019
# Epoch 29: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 12s 130us/sample - loss: 0.0032 - dense_5_loss: 0.0013 - dense_6_loss: 0.0019 - dense_5_mse: 0.0013 - dense_6_mse: 0.0019 - val_loss: 0.0029 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0017 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0017
# Epoch 30/100
# 92000/92469 [============================>.] - ETA: 0s - loss: 0.0030 - dense_5_loss: 0.0011 - dense_6_loss: 0.0018 - dense_5_mse: 0.0011 - dense_6_mse: 0.0018
# Epoch 30: val_loss improved from 0.00252 to 0.00252, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 11s 115us/sample - loss: 0.0030 - dense_5_loss: 0.0011 - dense_6_loss: 0.0018 - dense_5_mse: 0.0011 - dense_6_mse: 0.0018 - val_loss: 0.0025 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0014
# Epoch 31/100
# 92256/92469 [============================>.] - ETA: 0s - loss: 0.0031 - dense_5_loss: 0.0012 - dense_6_loss: 0.0020 - dense_5_mse: 0.0012 - dense_6_mse: 0.0020
# Epoch 31: val_loss improved from 0.00252 to 0.00252, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 10s 113us/sample - loss: 0.0031 - dense_5_loss: 0.0012 - dense_6_loss: 0.0020 - dense_5_mse: 0.0012 - dense_6_mse: 0.0020 - val_loss: 0.0025 - val_dense_5_loss: 9.9985e-04 - val_dense_6_loss: 0.0015 - val_dense_5_mse: 9.9980e-04 - val_dense_6_mse: 0.0015
# Epoch 32/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0029 - dense_5_loss: 0.0011 - dense_6_loss: 0.0018 - dense_5_mse: 0.0011 - dense_6_mse: 0.0018
# Epoch 32: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 12s 129us/sample - loss: 0.0029 - dense_5_loss: 0.0011 - dense_6_loss: 0.0018 - dense_5_mse: 0.0011 - dense_6_mse: 0.0018 - val_loss: 0.0031 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0020 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0020
# Epoch 33/100
# 92096/92469 [============================>.] - ETA: 0s - loss: 0.0032 - dense_5_loss: 0.0012 - dense_6_loss: 0.0020 - dense_5_mse: 0.0012 - dense_6_mse: 0.0020
# Epoch 33: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 9s 103us/sample - loss: 0.0032 - dense_5_loss: 0.0012 - dense_6_loss: 0.0020 - dense_5_mse: 0.0012 - dense_6_mse: 0.0020 - val_loss: 0.0030 - val_dense_5_loss: 9.7821e-04 - val_dense_6_loss: 0.0020 - val_dense_5_mse: 9.7836e-04 - val_dense_6_mse: 0.0020
# Epoch 34/100
# 92192/92469 [============================>.] - ETA: 0s - loss: 0.0026 - dense_5_loss: 0.0010 - dense_6_loss: 0.0016 - dense_5_mse: 0.0010 - dense_6_mse: 0.0016
# Epoch 34: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 9s 99us/sample - loss: 0.0026 - dense_5_loss: 0.0010 - dense_6_loss: 0.0016 - dense_5_mse: 0.0010 - dense_6_mse: 0.0016 - val_loss: 0.0027 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0014
# Epoch 35/100
# 92032/92469 [============================>.] - ETA: 0s - loss: 0.0028 - dense_5_loss: 0.0011 - dense_6_loss: 0.0017 - dense_5_mse: 0.0011 - dense_6_mse: 0.0017
# Epoch 35: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 10s 104us/sample - loss: 0.0028 - dense_5_loss: 0.0011 - dense_6_loss: 0.0018 - dense_5_mse: 0.0011 - dense_6_mse: 0.0018 - val_loss: 0.0046 - val_dense_5_loss: 0.0021 - val_dense_6_loss: 0.0024 - val_dense_5_mse: 0.0021 - val_dense_6_mse: 0.0024
# Epoch 36/100
# 92416/92469 [============================>.] - ETA: 0s - loss: 0.0027 - dense_5_loss: 9.9971e-04 - dense_6_loss: 0.0017 - dense_5_mse: 9.9971e-04 - dense_6_mse: 0.0017
# Epoch 36: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 10s 103us/sample - loss: 0.0027 - dense_5_loss: 9.9951e-04 - dense_6_loss: 0.0017 - dense_5_mse: 9.9953e-04 - dense_6_mse: 0.0017 - val_loss: 0.0032 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0018
# Epoch 37/100
# 92416/92469 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 9.2989e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.2989e-04 - dense_6_mse: 0.0016
# Epoch 37: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 10s 103us/sample - loss: 0.0025 - dense_5_loss: 9.3013e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.3012e-04 - dense_6_mse: 0.0016 - val_loss: 0.0031 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0020 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0020
# Epoch 38/100
# 92064/92469 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 9.3543e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.3543e-04 - dense_6_mse: 0.0016
# Epoch 38: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 9s 99us/sample - loss: 0.0025 - dense_5_loss: 9.3473e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.3473e-04 - dense_6_mse: 0.0016 - val_loss: 0.0031 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0019 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0019
# Epoch 39/100
# 92000/92469 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 9.3454e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.3454e-04 - dense_6_mse: 0.0016
# Epoch 39: val_loss did not improve from 0.00252
# 92469/92469 [==============================] - 9s 99us/sample - loss: 0.0025 - dense_5_loss: 9.3374e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.3373e-04 - dense_6_mse: 0.0016 - val_loss: 0.0030 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0018
# Epoch 40/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0028 - dense_5_loss: 0.0011 - dense_6_loss: 0.0017 - dense_5_mse: 0.0011 - dense_6_mse: 0.0017
# Epoch 40: val_loss improved from 0.00252 to 0.00244, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 14s 152us/sample - loss: 0.0028 - dense_5_loss: 0.0011 - dense_6_loss: 0.0017 - dense_5_mse: 0.0011 - dense_6_mse: 0.0017 - val_loss: 0.0024 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0013
# Epoch 41/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0025 - dense_5_loss: 9.8745e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.8749e-04 - dense_6_mse: 0.0015
# Epoch 41: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 10s 104us/sample - loss: 0.0025 - dense_5_loss: 9.8745e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.8749e-04 - dense_6_mse: 0.0015 - val_loss: 0.0044 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0030 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0030
# Epoch 42/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 8.8455e-04 - dense_6_loss: 0.0015 - dense_5_mse: 8.8455e-04 - dense_6_mse: 0.0015
# Epoch 42: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 12s 127us/sample - loss: 0.0024 - dense_5_loss: 8.8430e-04 - dense_6_loss: 0.0015 - dense_5_mse: 8.8431e-04 - dense_6_mse: 0.0015 - val_loss: 0.0028 - val_dense_5_loss: 0.0016 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0016 - val_dense_6_mse: 0.0013
# Epoch 43/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0030 - dense_5_loss: 0.0012 - dense_6_loss: 0.0018 - dense_5_mse: 0.0012 - dense_6_mse: 0.0018
# Epoch 43: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 9s 99us/sample - loss: 0.0030 - dense_5_loss: 0.0012 - dense_6_loss: 0.0018 - dense_5_mse: 0.0012 - dense_6_mse: 0.0018 - val_loss: 0.0031 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0020 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0020
# Epoch 44/100
# 92192/92469 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 8.9277e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.9277e-04 - dense_6_mse: 0.0014
# Epoch 44: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 12s 130us/sample - loss: 0.0023 - dense_5_loss: 8.9167e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.9173e-04 - dense_6_mse: 0.0014 - val_loss: 0.0033 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0021 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0021
# Epoch 45/100
# 92224/92469 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 9.1587e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.1587e-04 - dense_6_mse: 0.0015
# Epoch 45: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 10s 105us/sample - loss: 0.0025 - dense_5_loss: 9.1706e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.1704e-04 - dense_6_mse: 0.0015 - val_loss: 0.0033 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0021 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0021
# Epoch 46/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0021 - dense_5_loss: 8.3351e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.3331e-04 - dense_6_mse: 0.0013
# Epoch 46: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 12s 134us/sample - loss: 0.0021 - dense_5_loss: 8.3351e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.3331e-04 - dense_6_mse: 0.0013 - val_loss: 0.0027 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0013
# Epoch 47/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 8.6099e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.6099e-04 - dense_6_mse: 0.0014
# Epoch 47: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 9s 95us/sample - loss: 0.0023 - dense_5_loss: 8.6140e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.6141e-04 - dense_6_mse: 0.0014 - val_loss: 0.0029 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0017 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0017
# Epoch 48/100
# 92032/92469 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 9.5660e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.5660e-04 - dense_6_mse: 0.0016
# Epoch 48: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 12s 131us/sample - loss: 0.0025 - dense_5_loss: 9.5584e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.5557e-04 - dense_6_mse: 0.0016 - val_loss: 0.0025 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0012 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0012
# Epoch 49/100
# 92192/92469 [============================>.] - ETA: 0s - loss: 0.0026 - dense_5_loss: 9.8851e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.8851e-04 - dense_6_mse: 0.0016
# Epoch 49: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 9s 99us/sample - loss: 0.0026 - dense_5_loss: 9.8689e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.8693e-04 - dense_6_mse: 0.0016 - val_loss: 0.0031 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0017 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0017
# Epoch 50/100
# 92384/92469 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 8.4539e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.4539e-04 - dense_6_mse: 0.0014
# Epoch 50: val_loss did not improve from 0.00244
# 92469/92469 [==============================] - 12s 130us/sample - loss: 0.0022 - dense_5_loss: 8.4494e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.4499e-04 - dense_6_mse: 0.0014 - val_loss: 0.0026 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0014
# Epoch 51/100
# 92032/92469 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 9.4948e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.4948e-04 - dense_6_mse: 0.0015
# Epoch 51: val_loss improved from 0.00244 to 0.00224, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 92469/92469 [==============================] - 11s 115us/sample - loss: 0.0024 - dense_5_loss: 9.4794e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.4789e-04 - dense_6_mse: 0.0015 - val_loss: 0.0022 - val_dense_5_loss: 0.0010 - val_dense_6_loss: 0.0012 - val_dense_5_mse: 0.0010 - val_dense_6_mse: 0.0012
# Epoch 52/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0023 - dense_5_loss: 8.6482e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.6485e-04 - dense_6_mse: 0.0014
# Epoch 52: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 125us/sample - loss: 0.0023 - dense_5_loss: 8.6482e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.6485e-04 - dense_6_mse: 0.0014 - val_loss: 0.0024 - val_dense_5_loss: 0.0010 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 0.0010 - val_dense_6_mse: 0.0014
# Epoch 53/100
# 92096/92469 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 8.7045e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.7045e-04 - dense_6_mse: 0.0014
# Epoch 53: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 10s 105us/sample - loss: 0.0023 - dense_5_loss: 8.7089e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.7090e-04 - dense_6_mse: 0.0014 - val_loss: 0.0024 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0012 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0012
# Epoch 54/100
# 92384/92469 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 8.3495e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.3495e-04 - dense_6_mse: 0.0014
# Epoch 54: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 127us/sample - loss: 0.0022 - dense_5_loss: 8.3441e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.3447e-04 - dense_6_mse: 0.0014 - val_loss: 0.0027 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0015 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0015
# Epoch 55/100
# 92320/92469 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 8.2759e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.2759e-04 - dense_6_mse: 0.0013
# Epoch 55: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 10s 109us/sample - loss: 0.0021 - dense_5_loss: 8.2710e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.2713e-04 - dense_6_mse: 0.0013 - val_loss: 0.0024 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0013
# Epoch 56/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 8.7618e-04 - dense_6_loss: 0.0015 - dense_5_mse: 8.7618e-04 - dense_6_mse: 0.0015
# Epoch 56: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 9s 101us/sample - loss: 0.0024 - dense_5_loss: 8.7607e-04 - dense_6_loss: 0.0015 - dense_5_mse: 8.7611e-04 - dense_6_mse: 0.0015 - val_loss: 0.0030 - val_dense_5_loss: 0.0015 - val_dense_6_loss: 0.0015 - val_dense_5_mse: 0.0015 - val_dense_6_mse: 0.0015
# Epoch 57/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 8.3781e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.3781e-04 - dense_6_mse: 0.0014
# Epoch 57: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 131us/sample - loss: 0.0022 - dense_5_loss: 8.3679e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.3681e-04 - dense_6_mse: 0.0014 - val_loss: 0.0025 - val_dense_5_loss: 9.6869e-04 - val_dense_6_loss: 0.0015 - val_dense_5_mse: 9.6875e-04 - val_dense_6_mse: 0.0015
# Epoch 58/100
# 92192/92469 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 8.3691e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.3691e-04 - dense_6_mse: 0.0014
# Epoch 58: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 9s 97us/sample - loss: 0.0022 - dense_5_loss: 8.3653e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.3648e-04 - dense_6_mse: 0.0014 - val_loss: 0.0030 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0016 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0016
# Epoch 59/100
# 92448/92469 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 9.4643e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.4643e-04 - dense_6_mse: 0.0015
# Epoch 59: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 128us/sample - loss: 0.0024 - dense_5_loss: 9.4650e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.4648e-04 - dense_6_mse: 0.0015 - val_loss: 0.0032 - val_dense_5_loss: 0.0016 - val_dense_6_loss: 0.0016 - val_dense_5_mse: 0.0016 - val_dense_6_mse: 0.0016
# Epoch 60/100
# 92064/92469 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 9.0481e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.0481e-04 - dense_6_mse: 0.0014
# Epoch 60: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 9s 100us/sample - loss: 0.0023 - dense_5_loss: 9.0375e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.0369e-04 - dense_6_mse: 0.0014 - val_loss: 0.0022 - val_dense_5_loss: 9.9360e-04 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 9.9363e-04 - val_dense_6_mse: 0.0013
# Epoch 61/100
# 92224/92469 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 8.5369e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.5369e-04 - dense_6_mse: 0.0013
# Epoch 61: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 131us/sample - loss: 0.0022 - dense_5_loss: 8.5250e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.5255e-04 - dense_6_mse: 0.0013 - val_loss: 0.0026 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0015 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0015
# Epoch 62/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 7.9024e-04 - dense_6_loss: 0.0013 - dense_5_mse: 7.9024e-04 - dense_6_mse: 0.0013
# Epoch 62: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 9s 98us/sample - loss: 0.0020 - dense_5_loss: 7.9000e-04 - dense_6_loss: 0.0013 - dense_5_mse: 7.9006e-04 - dense_6_mse: 0.0013 - val_loss: 0.0029 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0018
# Epoch 63/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 7.7713e-04 - dense_6_loss: 0.0014 - dense_5_mse: 7.7713e-04 - dense_6_mse: 0.0014
# Epoch 63: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 130us/sample - loss: 0.0021 - dense_5_loss: 7.7651e-04 - dense_6_loss: 0.0014 - dense_5_mse: 7.7655e-04 - dense_6_mse: 0.0014 - val_loss: 0.0030 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0017 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0017
# Epoch 64/100
# 92128/92469 [============================>.] - ETA: 0s - loss: 0.0026 - dense_5_loss: 9.8895e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.8895e-04 - dense_6_mse: 0.0016
# Epoch 64: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 9s 99us/sample - loss: 0.0026 - dense_5_loss: 9.8975e-04 - dense_6_loss: 0.0016 - dense_5_mse: 9.8978e-04 - dense_6_mse: 0.0016 - val_loss: 0.0036 - val_dense_5_loss: 0.0019 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0019 - val_dense_6_mse: 0.0018
# Epoch 65/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0022 - dense_5_loss: 8.3236e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.3236e-04 - dense_6_mse: 0.0013
# Epoch 65: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 13s 137us/sample - loss: 0.0022 - dense_5_loss: 8.3236e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.3236e-04 - dense_6_mse: 0.0013 - val_loss: 0.0025 - val_dense_5_loss: 9.5052e-04 - val_dense_6_loss: 0.0016 - val_dense_5_mse: 9.5066e-04 - val_dense_6_mse: 0.0016
# Epoch 66/100
# 91936/92469 [============================>.] - ETA: 0s - loss: 0.0026 - dense_5_loss: 0.0010 - dense_6_loss: 0.0016 - dense_5_mse: 0.0010 - dense_6_mse: 0.0016
# Epoch 66: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 9s 99us/sample - loss: 0.0026 - dense_5_loss: 0.0010 - dense_6_loss: 0.0016 - dense_5_mse: 0.0010 - dense_6_mse: 0.0016 - val_loss: 0.0035 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0022 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0022
# Epoch 67/100
# 92448/92469 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 8.4048e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.4048e-04 - dense_6_mse: 0.0014
# Epoch 67: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 129us/sample - loss: 0.0023 - dense_5_loss: 8.4033e-04 - dense_6_loss: 0.0014 - dense_5_mse: 8.4038e-04 - dense_6_mse: 0.0014 - val_loss: 0.0030 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0018
# Epoch 68/100
# 92469/92469 [==============================] - ETA: 0s - loss: 0.0020 - dense_5_loss: 7.8064e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.8064e-04 - dense_6_mse: 0.0012
# Epoch 68: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 9s 96us/sample - loss: 0.0020 - dense_5_loss: 7.8064e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.8064e-04 - dense_6_mse: 0.0012 - val_loss: 0.0035 - val_dense_5_loss: 0.0010 - val_dense_6_loss: 0.0025 - val_dense_5_mse: 0.0010 - val_dense_6_mse: 0.0025
# Epoch 69/100
# 92224/92469 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 7.3667e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.3667e-04 - dense_6_mse: 0.0012
# Epoch 69: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 130us/sample - loss: 0.0019 - dense_5_loss: 7.3612e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.3615e-04 - dense_6_mse: 0.0012 - val_loss: 0.0025 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0013
# Epoch 70/100
# 92160/92469 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 7.5139e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.5139e-04 - dense_6_mse: 0.0012
# Epoch 70: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 9s 102us/sample - loss: 0.0020 - dense_5_loss: 7.5035e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.5038e-04 - dense_6_mse: 0.0012 - val_loss: 0.0023 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0012 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0012
# Epoch 71/100
# 92288/92469 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 8.2256e-04 - dense_6_loss: 0.0012 - dense_5_mse: 8.2256e-04 - dense_6_mse: 0.0012
# Epoch 71: val_loss did not improve from 0.00224
# 92469/92469 [==============================] - 12s 132us/sample - loss: 0.0020 - dense_5_loss: 8.2259e-04 - dense_6_loss: 0.0012 - dense_5_mse: 8.2266e-04 - dense_6_mse: 0.0012 - val_loss: 0.0030 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0020 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0020
# Epoch 71: early stopping
# ---Training time: 758.87725449 seconds ---

# %%
# # Save the model
# print(model.summary())
# plot_model(model, show_shapes=True)
# model.save('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/Reference_p5270/Reference/DD_Transfer_model_70_10_20.h5')

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)[0,] 
y_predtrain_V =np.array(y_predtrain)[1,] 

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS) 
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS)) 

train_r2_V = r2_score(Y_train_V,y_predtrain_V ) 
train_rmse_V = np.sqrt(mean_squared_error(Y_train_V, y_predtrain_V )) 

# Model Performance: Validation 
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)[0,] 
y_predval_V = np.array(y_predval)[1,] 

val_r2_SS = r2_score(Y_val_SS, y_predval_SS) 
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS)) 

val_r2_V = r2_score(Y_val_V, y_predval_V) 
val_rmse_V = np.sqrt(mean_squared_error(Y_val_V, y_predval_V)) 

# Model Performance: Testing 
y_predtest = model.predict([x_test])
y_predtest_SS =np.array(y_predtest)[0,] 
y_predtest_V = np.array(y_predtest)[1,] 

test_r2_SS = r2_score(y_test_SS,y_predtest_SS) 
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS)) 

test_r2_V = r2_score(y_test_V,y_predtest_V) 
test_rmse_V = np.sqrt(mean_squared_error(y_test_V, y_predtest_V)) 

# Print R2 Results 
print("R2 scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_r2_SS , train_r2_V))
print("R2 scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_r2_SS , val_r2_V))
print("R2 scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_r2_SS , test_r2_V))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_rmse_SS , train_rmse_V))
print("RMSE scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_rmse_SS , val_rmse_V))
print("RMSE scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_rmse_SS , test_rmse_V))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# R2 scores: Train (SS) - 0.98270, Train (V) - 0.88317
# R2 scores: Validation (SS) - 0.97053, Validation (V) - 0.89166
# R2 scores: Testing (SS) - 0.93410, Testing (V) - 0.90273
# RMSE scores: Train (SS) - 0.02144, Train (V) - 0.03288
# RMSE scores: Validation (SS) - 0.03230, Validation (V) - 0.03984
# RMSE scores: Testing (SS) - 0.04732, Testing (V) - 0.03667

# %%
# Inverse scaling: SS 
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# Inverse scaling: V
Y_train_V = scaler_v.inverse_transform(Y_train_V)
Y_val_V = scaler_v.inverse_transform(Y_val_V)
y_test_V = scaler_v.inverse_transform(y_test_V)
y_predtrain_V = scaler_v.inverse_transform(y_predtrain_V)
y_predval_V = scaler_v.inverse_transform(y_predval_V)
y_predtest_V = scaler_v.inverse_transform(y_predtest_V)

# %%
# Overall plot: SS & V 
ttime = df['Time'][n_steps:]
t1, testtime = train_test_split(ttime, test_size=0.2, shuffle=False)
traintime, valtime = train_test_split(t1, test_size=0.125, shuffle=False)

traintime = traintime[0:92469] 

fig = plt.figure(1, figsize=(20,6))
plt.plot(ttime, ydf_SS)
plt.plot(traintime, y_predtrain_SS)
plt.plot(valtime, y_predval_SS)
plt.plot(testtime, y_predtest_SS)
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

fig = plt.figure(2, figsize=(20,6))
plt.plot(ttime, ydf_V)
plt.plot(traintime, y_predtrain_V)
plt.plot(valtime,  y_predval_V)
plt.plot(testtime, y_predtest_V)
plt.xlabel('Time (s)')
plt.ylabel('Slip Rate (um/s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

# %%
# Individual plot: SS

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Shear Stress (MPa)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SS, y_predtrain_SS, 'Training data', '')
results_plot(2, valtime, Y_val_SS, y_predval_SS, 'Validation data', 'g')
results_plot(3, testtime, y_test_SS, y_predtest_SS, 'Testing data', 'r')

# %%
# Individual plot: V

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Slip Rate (um/s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_V, y_predtrain_V, 'Training data', '')
results_plot(2, valtime, Y_val_V, y_predval_V, 'Validation data', 'g')
results_plot(3, testtime, y_test_V, y_predtest_V, 'Testing data', 'r')

# %%
# # Extract Data

# # Time 
# savetxt('Whole_time.csv', ttime, delimiter=',')
# savetxt('traintime.csv', traintime, delimiter=',')
# savetxt('valtime.csv', valtime, delimiter=',')
# savetxt('testtime.csv', testtime, delimiter=',')

# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# # V
# savetxt('Y_train_V.csv', Y_train_V, delimiter=',')
# savetxt('Y_val_V.csv', Y_val_V, delimiter=',')
# savetxt('y_test_V.csv', y_test_V, delimiter=',')
# savetxt('y_predtrain_V.csv', y_predtrain_V, delimiter=',')
# savetxt('y_predval_V.csv', y_predval_V, delimiter=',')
# savetxt('y_predtest_V.csv', y_predtest_V, delimiter=',')

# # Download
# files.download('Whole_time.csv')
# files.download('traintime.csv')
# files.download('valtime.csv')
# files.download('testtime.csv')

# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')

# files.download('Y_train_V.csv')
# files.download('Y_val_V.csv')
# files.download('y_test_V.csv')
# files.download('y_predtrain_V.csv')
# files.download('y_predval_V.csv')
# files.download('y_predtest_V.csv')

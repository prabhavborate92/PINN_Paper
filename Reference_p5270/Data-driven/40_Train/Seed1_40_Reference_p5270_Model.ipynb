# %%
# Load Libraries 
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
from keras.utils.vis_utils import plot_model
np.random.seed(0)   
tf.random.set_seed(0)

# %%
# Mount Google Drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1] 
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel()})
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel()}) 
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(),'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt', 'C_filt','Time','V_filt','SS']]
df_SS = df[['freqQAmpI_filt','C_filt','SS']] 
df_V = df[['freqQAmpI_filt','C_filt','V_filt']] 
df_A = df[['freqQAmpI_filt','C_filt','freqQAmpI_filt']]
df_WV = df[['freqQAmpI_filt','C_filt','C_filt']]
xdf = df[['freqQAmpI_filt', 'C_filt']]
ydf = df[['SS','V_filt']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#          freqQAmpI_filt       C_filt
# 0         31453.223522  5490.232850
# 1         31438.277060  5490.239343
# 2         31421.341616  5490.240838
# 3         31409.798761  5490.232728
# 4         31398.815589  5490.222463
# ...                ...          ...
# 132394    31055.686766  5457.051859
# 132395    31041.955345  5457.082380
# 132396    31035.059531  5457.111463
# 132397    31020.001291  5457.126443
# 132398    31012.016780  5457.151945
#
# [132399 rows x 2 columns]
# Target Data:
#                SS    V_filt
# 0       5.656166  1.201004
# 1       5.657157  1.243144
# 2       5.658317  1.264215
# 3       5.659499  1.243144
# 4       5.660404  1.222074
# ...          ...       ...
# 132394  5.471059  1.285285
# 132395  5.474545  0.948161
# 132396  5.478286  1.158863
# 132397  5.481751  1.201004
# 132398  5.484813  0.526756
#
# [132399 rows x 2 columns]

# %%
# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (V)
arr = df_V.to_numpy()
n_steps = 300
xdf, ydf_V = create_timesteps(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
n_steps = 300
xdf, ydf_A = create_timesteps(arr, n_steps)

# Preprocessing (WV)
arr = df_WV.to_numpy()
n_steps = 300
xdf, ydf_WV = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (V), Y = ', np.shape(ydf_V))

# Reshape 
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132099, 300, 2)
# Target shape (SS), Y =  (132099,)
# Target shape (V), Y =  (132099,)
# After reshaping, X =  (132099, 600)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Split into train-val-test (V)
x_train, x_test, y_train_V, y_test_V = train_test_split(xdf, ydf_V, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_V, Y_val_V = train_test_split(x_train, y_train_V, test_size=0.125, shuffle=False)

# Select Train
X_train = X_train[39629:92469] 
Y_train_SS = Y_train_SS[39629:92469]
Y_train_V = Y_train_V[39629:92469]

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 52840
# Validation samples: 13210
# Testing samples: 26420

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Normalize the output: V
scaler_v = MinMaxScaler()
Y_train_V = pd.DataFrame(scaler_v.fit_transform(Y_train_V.reshape(-1, 1)))
Y_val_V = pd.DataFrame(scaler_v.transform(Y_val_V.reshape(-1, 1)))
y_test_V = pd.DataFrame(scaler_v.transform(y_test_V.reshape(-1, 1)))

# %% [markdown]
# **Define Data-Driven Model**

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(600),name='X_train')    

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)
  v_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred,v_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  X_train (InputLayer)           [(None, 600)]        0           []
#
#  dense (Dense)                  (None, 128)          76928       ['X_train[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 8)            136         ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            9           ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 1)            9           ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 87,946
# Trainable params: 87,946
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')  
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check', monitor='val_loss', verbose=1, save_best_only=True, mode='min')  
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS,Y_train_V], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS,Y_val_V]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 52840 samples, validate on 13210 samples
# Epoch 1/100
# 52736/52840 [============================>.] - ETA: 0s - loss: 0.0398 - dense_5_loss: 0.0303 - dense_6_loss: 0.0095 - dense_5_mse: 0.0303 - dense_6_mse: 0.0095
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2045: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 1: val_loss improved from inf to 0.01964, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 9s 161us/sample - loss: 0.0397 - dense_5_loss: 0.0302 - dense_6_loss: 0.0095 - dense_5_mse: 0.0302 - dense_6_mse: 0.0095 - val_loss: 0.0196 - val_dense_5_loss: 0.0050 - val_dense_6_loss: 0.0146 - val_dense_5_mse: 0.0050 - val_dense_6_mse: 0.0146
# Epoch 2/100
# 52672/52840 [============================>.] - ETA: 0s - loss: 0.0122 - dense_5_loss: 0.0030 - dense_6_loss: 0.0091 - dense_5_mse: 0.0030 - dense_6_mse: 0.0091
# Epoch 2: val_loss improved from 0.01964 to 0.01313, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 6s 116us/sample - loss: 0.0121 - dense_5_loss: 0.0030 - dense_6_loss: 0.0091 - dense_5_mse: 0.0030 - dense_6_mse: 0.0091 - val_loss: 0.0131 - val_dense_5_loss: 0.0032 - val_dense_6_loss: 0.0099 - val_dense_5_mse: 0.0032 - val_dense_6_mse: 0.0099
# Epoch 3/100
# 52384/52840 [============================>.] - ETA: 0s - loss: 0.0078 - dense_5_loss: 0.0024 - dense_6_loss: 0.0054 - dense_5_mse: 0.0024 - dense_6_mse: 0.0054
# Epoch 3: val_loss did not improve from 0.01313
# 52840/52840 [==============================] - 5s 90us/sample - loss: 0.0078 - dense_5_loss: 0.0025 - dense_6_loss: 0.0054 - dense_5_mse: 0.0025 - dense_6_mse: 0.0054 - val_loss: 0.0137 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 0.0106 - val_dense_5_mse: 0.0031 - val_dense_6_mse: 0.0106
# Epoch 4/100
# 52608/52840 [============================>.] - ETA: 0s - loss: 0.0051 - dense_5_loss: 0.0019 - dense_6_loss: 0.0032 - dense_5_mse: 0.0019 - dense_6_mse: 0.0032
# Epoch 4: val_loss improved from 0.01313 to 0.00539, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 6s 122us/sample - loss: 0.0051 - dense_5_loss: 0.0019 - dense_6_loss: 0.0032 - dense_5_mse: 0.0019 - dense_6_mse: 0.0032 - val_loss: 0.0054 - val_dense_5_loss: 0.0019 - val_dense_6_loss: 0.0035 - val_dense_5_mse: 0.0019 - val_dense_6_mse: 0.0035
# Epoch 5/100
# 52544/52840 [============================>.] - ETA: 0s - loss: 0.0050 - dense_5_loss: 0.0019 - dense_6_loss: 0.0030 - dense_5_mse: 0.0019 - dense_6_mse: 0.0030
# Epoch 5: val_loss did not improve from 0.00539
# 52840/52840 [==============================] - 5s 94us/sample - loss: 0.0049 - dense_5_loss: 0.0019 - dense_6_loss: 0.0030 - dense_5_mse: 0.0019 - dense_6_mse: 0.0030 - val_loss: 0.0058 - val_dense_5_loss: 0.0020 - val_dense_6_loss: 0.0038 - val_dense_5_mse: 0.0020 - val_dense_6_mse: 0.0038
# Epoch 6/100
# 52640/52840 [============================>.] - ETA: 0s - loss: 0.0043 - dense_5_loss: 0.0017 - dense_6_loss: 0.0026 - dense_5_mse: 0.0017 - dense_6_mse: 0.0026
# Epoch 6: val_loss did not improve from 0.00539
# 52840/52840 [==============================] - 6s 108us/sample - loss: 0.0043 - dense_5_loss: 0.0017 - dense_6_loss: 0.0026 - dense_5_mse: 0.0017 - dense_6_mse: 0.0026 - val_loss: 0.0058 - val_dense_5_loss: 0.0017 - val_dense_6_loss: 0.0041 - val_dense_5_mse: 0.0017 - val_dense_6_mse: 0.0041
# Epoch 7/100
# 52800/52840 [============================>.] - ETA: 0s - loss: 0.0041 - dense_5_loss: 0.0016 - dense_6_loss: 0.0025 - dense_5_mse: 0.0016 - dense_6_mse: 0.0025
# Epoch 7: val_loss did not improve from 0.00539
# 52840/52840 [==============================] - 8s 155us/sample - loss: 0.0041 - dense_5_loss: 0.0016 - dense_6_loss: 0.0025 - dense_5_mse: 0.0016 - dense_6_mse: 0.0025 - val_loss: 0.0069 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 0.0023 - val_dense_5_mse: 0.0046 - val_dense_6_mse: 0.0023
# Epoch 8/100
# 52576/52840 [============================>.] - ETA: 0s - loss: 0.0038 - dense_5_loss: 0.0016 - dense_6_loss: 0.0023 - dense_5_mse: 0.0016 - dense_6_mse: 0.0023
# Epoch 8: val_loss did not improve from 0.00539
# 52840/52840 [==============================] - 5s 95us/sample - loss: 0.0038 - dense_5_loss: 0.0016 - dense_6_loss: 0.0023 - dense_5_mse: 0.0016 - dense_6_mse: 0.0023 - val_loss: 0.0054 - val_dense_5_loss: 0.0021 - val_dense_6_loss: 0.0033 - val_dense_5_mse: 0.0021 - val_dense_6_mse: 0.0033
# Epoch 9/100
# 52840/52840 [==============================] - ETA: 0s - loss: 0.0038 - dense_5_loss: 0.0015 - dense_6_loss: 0.0023 - dense_5_mse: 0.0015 - dense_6_mse: 0.0023
# Epoch 9: val_loss improved from 0.00539 to 0.00422, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 8s 152us/sample - loss: 0.0038 - dense_5_loss: 0.0015 - dense_6_loss: 0.0023 - dense_5_mse: 0.0015 - dense_6_mse: 0.0023 - val_loss: 0.0042 - val_dense_5_loss: 0.0017 - val_dense_6_loss: 0.0026 - val_dense_5_mse: 0.0017 - val_dense_6_mse: 0.0026
# Epoch 10/100
# 52416/52840 [============================>.] - ETA: 0s - loss: 0.0039 - dense_5_loss: 0.0015 - dense_6_loss: 0.0023 - dense_5_mse: 0.0015 - dense_6_mse: 0.0023
# Epoch 10: val_loss did not improve from 0.00422
# 52840/52840 [==============================] - 5s 90us/sample - loss: 0.0039 - dense_5_loss: 0.0015 - dense_6_loss: 0.0023 - dense_5_mse: 0.0015 - dense_6_mse: 0.0023 - val_loss: 0.0059 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 0.0028 - val_dense_5_mse: 0.0031 - val_dense_6_mse: 0.0028
# Epoch 11/100
# 52840/52840 [==============================] - ETA: 0s - loss: 0.0034 - dense_5_loss: 0.0014 - dense_6_loss: 0.0020 - dense_5_mse: 0.0014 - dense_6_mse: 0.0020
# Epoch 11: val_loss improved from 0.00422 to 0.00381, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 6s 117us/sample - loss: 0.0034 - dense_5_loss: 0.0014 - dense_6_loss: 0.0020 - dense_5_mse: 0.0014 - dense_6_mse: 0.0020 - val_loss: 0.0038 - val_dense_5_loss: 0.0017 - val_dense_6_loss: 0.0021 - val_dense_5_mse: 0.0017 - val_dense_6_mse: 0.0021
# Epoch 12/100
# 52384/52840 [============================>.] - ETA: 0s - loss: 0.0033 - dense_5_loss: 0.0013 - dense_6_loss: 0.0020 - dense_5_mse: 0.0013 - dense_6_mse: 0.0020
# Epoch 12: val_loss did not improve from 0.00381
# 52840/52840 [==============================] - 5s 92us/sample - loss: 0.0034 - dense_5_loss: 0.0013 - dense_6_loss: 0.0020 - dense_5_mse: 0.0013 - dense_6_mse: 0.0020 - val_loss: 0.0071 - val_dense_5_loss: 0.0022 - val_dense_6_loss: 0.0049 - val_dense_5_mse: 0.0022 - val_dense_6_mse: 0.0049
# Epoch 13/100
# 52544/52840 [============================>.] - ETA: 0s - loss: 0.0033 - dense_5_loss: 0.0013 - dense_6_loss: 0.0020 - dense_5_mse: 0.0013 - dense_6_mse: 0.0020
# Epoch 13: val_loss did not improve from 0.00381
# 52840/52840 [==============================] - 6s 106us/sample - loss: 0.0033 - dense_5_loss: 0.0013 - dense_6_loss: 0.0020 - dense_5_mse: 0.0013 - dense_6_mse: 0.0020 - val_loss: 0.0062 - val_dense_5_loss: 0.0025 - val_dense_6_loss: 0.0038 - val_dense_5_mse: 0.0025 - val_dense_6_mse: 0.0038
# Epoch 14/100
# 52768/52840 [============================>.] - ETA: 0s - loss: 0.0028 - dense_5_loss: 0.0012 - dense_6_loss: 0.0017 - dense_5_mse: 0.0012 - dense_6_mse: 0.0017
# Epoch 14: val_loss improved from 0.00381 to 0.00360, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 6s 120us/sample - loss: 0.0028 - dense_5_loss: 0.0012 - dense_6_loss: 0.0017 - dense_5_mse: 0.0012 - dense_6_mse: 0.0017 - val_loss: 0.0036 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0023 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0023
# Epoch 15/100
# 52576/52840 [============================>.] - ETA: 0s - loss: 0.0031 - dense_5_loss: 0.0013 - dense_6_loss: 0.0019 - dense_5_mse: 0.0013 - dense_6_mse: 0.0019
# Epoch 15: val_loss did not improve from 0.00360
# 52840/52840 [==============================] - 5s 90us/sample - loss: 0.0031 - dense_5_loss: 0.0013 - dense_6_loss: 0.0019 - dense_5_mse: 0.0013 - dense_6_mse: 0.0019 - val_loss: 0.0053 - val_dense_5_loss: 0.0021 - val_dense_6_loss: 0.0032 - val_dense_5_mse: 0.0021 - val_dense_6_mse: 0.0032
# Epoch 16/100
# 52544/52840 [============================>.] - ETA: 0s - loss: 0.0029 - dense_5_loss: 0.0012 - dense_6_loss: 0.0017 - dense_5_mse: 0.0012 - dense_6_mse: 0.0017
# Epoch 16: val_loss improved from 0.00360 to 0.00337, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 7s 133us/sample - loss: 0.0029 - dense_5_loss: 0.0012 - dense_6_loss: 0.0017 - dense_5_mse: 0.0012 - dense_6_mse: 0.0017 - val_loss: 0.0034 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0019 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0019
# Epoch 17/100
# 52736/52840 [============================>.] - ETA: 0s - loss: 0.0027 - dense_5_loss: 0.0011 - dense_6_loss: 0.0016 - dense_5_mse: 0.0011 - dense_6_mse: 0.0016
# Epoch 17: val_loss improved from 0.00337 to 0.00301, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 6s 115us/sample - loss: 0.0027 - dense_5_loss: 0.0011 - dense_6_loss: 0.0016 - dense_5_mse: 0.0011 - dense_6_mse: 0.0016 - val_loss: 0.0030 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0019 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0019
# Epoch 18/100
# 52480/52840 [============================>.] - ETA: 0s - loss: 0.0027 - dense_5_loss: 0.0011 - dense_6_loss: 0.0016 - dense_5_mse: 0.0011 - dense_6_mse: 0.0016
# Epoch 18: val_loss improved from 0.00301 to 0.00287, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 7s 133us/sample - loss: 0.0027 - dense_5_loss: 0.0011 - dense_6_loss: 0.0016 - dense_5_mse: 0.0011 - dense_6_mse: 0.0016 - val_loss: 0.0029 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0018
# Epoch 19/100
# 52352/52840 [============================>.] - ETA: 0s - loss: 0.0025 - dense_5_loss: 0.0010 - dense_6_loss: 0.0015 - dense_5_mse: 0.0010 - dense_6_mse: 0.0015
# Epoch 19: val_loss did not improve from 0.00287
# 52840/52840 [==============================] - 5s 92us/sample - loss: 0.0025 - dense_5_loss: 0.0010 - dense_6_loss: 0.0015 - dense_5_mse: 0.0010 - dense_6_mse: 0.0015 - val_loss: 0.0030 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0018
# Epoch 20/100
# 52576/52840 [============================>.] - ETA: 0s - loss: 0.0027 - dense_5_loss: 0.0011 - dense_6_loss: 0.0016 - dense_5_mse: 0.0011 - dense_6_mse: 0.0016
# Epoch 20: val_loss improved from 0.00287 to 0.00270, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 7s 140us/sample - loss: 0.0027 - dense_5_loss: 0.0011 - dense_6_loss: 0.0016 - dense_5_mse: 0.0011 - dense_6_mse: 0.0016 - val_loss: 0.0027 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0013
# Epoch 21/100
# 52224/52840 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 9.8259e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.8259e-04 - dense_6_mse: 0.0014
# Epoch 21: val_loss did not improve from 0.00270
# 52840/52840 [==============================] - 5s 89us/sample - loss: 0.0024 - dense_5_loss: 9.8027e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.8056e-04 - dense_6_mse: 0.0014 - val_loss: 0.0030 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0019 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0019
# Epoch 22/100
# 52800/52840 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 9.1580e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.1580e-04 - dense_6_mse: 0.0014
# Epoch 22: val_loss did not improve from 0.00270
# 52840/52840 [==============================] - 6s 104us/sample - loss: 0.0023 - dense_5_loss: 9.1548e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.1564e-04 - dense_6_mse: 0.0014 - val_loss: 0.0047 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0034 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0034
# Epoch 23/100
# 52256/52840 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 9.6761e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.6761e-04 - dense_6_mse: 0.0014
# Epoch 23: val_loss improved from 0.00270 to 0.00254, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 6s 115us/sample - loss: 0.0024 - dense_5_loss: 9.6251e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.6279e-04 - dense_6_mse: 0.0014 - val_loss: 0.0025 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0013
# Epoch 24/100
# 52608/52840 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 9.4812e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.4812e-04 - dense_6_mse: 0.0014
# Epoch 24: val_loss did not improve from 0.00254
# 52840/52840 [==============================] - 5s 90us/sample - loss: 0.0024 - dense_5_loss: 9.5061e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.5046e-04 - dense_6_mse: 0.0014 - val_loss: 0.0072 - val_dense_5_loss: 0.0020 - val_dense_6_loss: 0.0052 - val_dense_5_mse: 0.0020 - val_dense_6_mse: 0.0052
# Epoch 25/100
# 52576/52840 [============================>.] - ETA: 0s - loss: 0.0022 - dense_5_loss: 8.7835e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.7835e-04 - dense_6_mse: 0.0013
# Epoch 25: val_loss did not improve from 0.00254
# 52840/52840 [==============================] - 5s 96us/sample - loss: 0.0022 - dense_5_loss: 8.7914e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.7924e-04 - dense_6_mse: 0.0013 - val_loss: 0.0044 - val_dense_5_loss: 0.0022 - val_dense_6_loss: 0.0023 - val_dense_5_mse: 0.0022 - val_dense_6_mse: 0.0023
# Epoch 26/100
# 52840/52840 [==============================] - ETA: 0s - loss: 0.0022 - dense_5_loss: 9.4618e-04 - dense_6_loss: 0.0013 - dense_5_mse: 9.4650e-04 - dense_6_mse: 0.0013
# Epoch 26: val_loss improved from 0.00254 to 0.00248, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 6s 118us/sample - loss: 0.0022 - dense_5_loss: 9.4618e-04 - dense_6_loss: 0.0013 - dense_5_mse: 9.4650e-04 - dense_6_mse: 0.0013 - val_loss: 0.0025 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0014
# Epoch 27/100
# 52704/52840 [============================>.] - ETA: 0s - loss: 0.0024 - dense_5_loss: 9.2309e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.2309e-04 - dense_6_mse: 0.0015
# Epoch 27: val_loss did not improve from 0.00248
# 52840/52840 [==============================] - 6s 109us/sample - loss: 0.0024 - dense_5_loss: 9.2209e-04 - dense_6_loss: 0.0015 - dense_5_mse: 9.2203e-04 - dense_6_mse: 0.0015 - val_loss: 0.0034 - val_dense_5_loss: 0.0010 - val_dense_6_loss: 0.0024 - val_dense_5_mse: 0.0010 - val_dense_6_mse: 0.0024
# Epoch 28/100
# 52576/52840 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 9.3710e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.3710e-04 - dense_6_mse: 0.0014
# Epoch 28: val_loss did not improve from 0.00248
# 52840/52840 [==============================] - 5s 90us/sample - loss: 0.0023 - dense_5_loss: 9.3496e-04 - dense_6_loss: 0.0014 - dense_5_mse: 9.3511e-04 - dense_6_mse: 0.0014 - val_loss: 0.0032 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0018
# Epoch 29/100
# 52544/52840 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 8.1981e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.1981e-04 - dense_6_mse: 0.0013
# Epoch 29: val_loss improved from 0.00248 to 0.00242, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 7s 124us/sample - loss: 0.0021 - dense_5_loss: 8.1882e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.1910e-04 - dense_6_mse: 0.0013 - val_loss: 0.0024 - val_dense_5_loss: 9.7854e-04 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 9.7863e-04 - val_dense_6_mse: 0.0014
# Epoch 30/100
# 52736/52840 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 7.8517e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.8517e-04 - dense_6_mse: 0.0011
# Epoch 30: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 5s 91us/sample - loss: 0.0018 - dense_5_loss: 7.8583e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.8534e-04 - dense_6_mse: 0.0011 - val_loss: 0.0029 - val_dense_5_loss: 0.0016 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 0.0016 - val_dense_6_mse: 0.0014
# Epoch 31/100
# 52840/52840 [==============================] - ETA: 0s - loss: 0.0021 - dense_5_loss: 8.3931e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.3949e-04 - dense_6_mse: 0.0013
# Epoch 31: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 6s 110us/sample - loss: 0.0021 - dense_5_loss: 8.3931e-04 - dense_6_loss: 0.0013 - dense_5_mse: 8.3949e-04 - dense_6_mse: 0.0013 - val_loss: 0.0026 - val_dense_5_loss: 9.6594e-04 - val_dense_6_loss: 0.0016 - val_dense_5_mse: 9.6609e-04 - val_dense_6_mse: 0.0016
# Epoch 32/100
# 52640/52840 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 7.3213e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.3213e-04 - dense_6_mse: 0.0011
# Epoch 32: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 5s 90us/sample - loss: 0.0018 - dense_5_loss: 7.3233e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.3223e-04 - dense_6_mse: 0.0011 - val_loss: 0.0065 - val_dense_5_loss: 0.0022 - val_dense_6_loss: 0.0043 - val_dense_5_mse: 0.0022 - val_dense_6_mse: 0.0043
# Epoch 33/100
# 52704/52840 [============================>.] - ETA: 0s - loss: 0.0031 - dense_5_loss: 0.0012 - dense_6_loss: 0.0019 - dense_5_mse: 0.0012 - dense_6_mse: 0.0019
# Epoch 33: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 5s 99us/sample - loss: 0.0031 - dense_5_loss: 0.0012 - dense_6_loss: 0.0019 - dense_5_mse: 0.0012 - dense_6_mse: 0.0019 - val_loss: 0.0032 - val_dense_5_loss: 0.0018 - val_dense_6_loss: 0.0014 - val_dense_5_mse: 0.0018 - val_dense_6_mse: 0.0014
# Epoch 34/100
# 52352/52840 [============================>.] - ETA: 0s - loss: 0.0023 - dense_5_loss: 9.3886e-04 - dense_6_loss: 0.0013 - dense_5_mse: 9.3886e-04 - dense_6_mse: 0.0013
# Epoch 34: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 5s 89us/sample - loss: 0.0023 - dense_5_loss: 9.3915e-04 - dense_6_loss: 0.0013 - dense_5_mse: 9.3878e-04 - dense_6_mse: 0.0013 - val_loss: 0.0044 - val_dense_5_loss: 0.0020 - val_dense_6_loss: 0.0024 - val_dense_5_mse: 0.0020 - val_dense_6_mse: 0.0024
# Epoch 35/100
# 52832/52840 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 9.1608e-04 - dense_6_loss: 0.0012 - dense_5_mse: 9.1608e-04 - dense_6_mse: 0.0012
# Epoch 35: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 7s 125us/sample - loss: 0.0021 - dense_5_loss: 9.1587e-04 - dense_6_loss: 0.0012 - dense_5_mse: 9.1603e-04 - dense_6_mse: 0.0012 - val_loss: 0.0030 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0015 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0015
# Epoch 36/100
# 52832/52840 [============================>.] - ETA: 0s - loss: 0.0021 - dense_5_loss: 8.5689e-04 - dense_6_loss: 0.0012 - dense_5_mse: 8.5689e-04 - dense_6_mse: 0.0012
# Epoch 36: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 6s 109us/sample - loss: 0.0021 - dense_5_loss: 8.5666e-04 - dense_6_loss: 0.0012 - dense_5_mse: 8.5683e-04 - dense_6_mse: 0.0012 - val_loss: 0.0028 - val_dense_5_loss: 0.0016 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0016 - val_dense_6_mse: 0.0013
# Epoch 37/100
# 52704/52840 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 8.1238e-04 - dense_6_loss: 0.0012 - dense_5_mse: 8.1238e-04 - dense_6_mse: 0.0012
# Epoch 37: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 5s 103us/sample - loss: 0.0020 - dense_5_loss: 8.1365e-04 - dense_6_loss: 0.0012 - dense_5_mse: 8.1371e-04 - dense_6_mse: 0.0012 - val_loss: 0.0036 - val_dense_5_loss: 0.0016 - val_dense_6_loss: 0.0020 - val_dense_5_mse: 0.0016 - val_dense_6_mse: 0.0020
# Epoch 38/100
# 52736/52840 [============================>.] - ETA: 0s - loss: 0.0020 - dense_5_loss: 7.7733e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.7733e-04 - dense_6_mse: 0.0012
# Epoch 38: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 6s 112us/sample - loss: 0.0020 - dense_5_loss: 7.7616e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.7644e-04 - dense_6_mse: 0.0012 - val_loss: 0.0041 - val_dense_5_loss: 0.0017 - val_dense_6_loss: 0.0024 - val_dense_5_mse: 0.0017 - val_dense_6_mse: 0.0024
# Epoch 39/100
# 52448/52840 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 7.6614e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.6614e-04 - dense_6_mse: 0.0011
# Epoch 39: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 5s 89us/sample - loss: 0.0019 - dense_5_loss: 7.6603e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.6632e-04 - dense_6_mse: 0.0011 - val_loss: 0.0038 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0028 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0028
# Epoch 40/100
# 52544/52840 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 7.7213e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.7213e-04 - dense_6_mse: 0.0011
# Epoch 40: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 6s 107us/sample - loss: 0.0019 - dense_5_loss: 7.7070e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.7090e-04 - dense_6_mse: 0.0011 - val_loss: 0.0030 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0018
# Epoch 41/100
# 52800/52840 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 7.8607e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.8607e-04 - dense_6_mse: 0.0011
# Epoch 41: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 5s 91us/sample - loss: 0.0019 - dense_5_loss: 7.8575e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.8597e-04 - dense_6_mse: 0.0011 - val_loss: 0.0026 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0012 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0012
# Epoch 42/100
# 52832/52840 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 7.1499e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.1499e-04 - dense_6_mse: 0.0011
# Epoch 42: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 6s 107us/sample - loss: 0.0018 - dense_5_loss: 7.1470e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.1491e-04 - dense_6_mse: 0.0011 - val_loss: 0.0025 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0012 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0012
# Epoch 43/100
# 52800/52840 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 6.9483e-04 - dense_6_loss: 9.6401e-04 - dense_5_mse: 6.9483e-04 - dense_6_mse: 9.6401e-04
# Epoch 43: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 5s 92us/sample - loss: 0.0017 - dense_5_loss: 6.9438e-04 - dense_6_loss: 9.6417e-04 - dense_5_mse: 6.9459e-04 - dense_6_mse: 9.6460e-04 - val_loss: 0.0025 - val_dense_5_loss: 0.0015 - val_dense_6_loss: 9.7670e-04 - val_dense_5_mse: 0.0015 - val_dense_6_mse: 9.7711e-04
# Epoch 44/100
# 52736/52840 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 7.7228e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.7228e-04 - dense_6_mse: 0.0012
# Epoch 44: val_loss did not improve from 0.00242
# 52840/52840 [==============================] - 6s 109us/sample - loss: 0.0019 - dense_5_loss: 7.7207e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.7222e-04 - dense_6_mse: 0.0012 - val_loss: 0.0027 - val_dense_5_loss: 0.0014 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0014 - val_dense_6_mse: 0.0013
# Epoch 45/100
# 52416/52840 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 7.2288e-04 - dense_6_loss: 9.9683e-04 - dense_5_mse: 7.2288e-04 - dense_6_mse: 9.9683e-04
# Epoch 45: val_loss improved from 0.00242 to 0.00229, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# WARNING:absl:Function `_wrapped_model` contains input name(s) X_train with unsupported characters which will be renamed to x_train in the SavedModel.
# 52840/52840 [==============================] - 6s 120us/sample - loss: 0.0017 - dense_5_loss: 7.2209e-04 - dense_6_loss: 9.9334e-04 - dense_5_mse: 7.2223e-04 - dense_6_mse: 9.9379e-04 - val_loss: 0.0023 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0011 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0011
# Epoch 46/100
# 52800/52840 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 6.7769e-04 - dense_6_loss: 0.0011 - dense_5_mse: 6.7769e-04 - dense_6_mse: 0.0011
# Epoch 46: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 95us/sample - loss: 0.0018 - dense_5_loss: 6.7851e-04 - dense_6_loss: 0.0011 - dense_5_mse: 6.7821e-04 - dense_6_mse: 0.0011 - val_loss: 0.0030 - val_dense_5_loss: 0.0019 - val_dense_6_loss: 0.0011 - val_dense_5_mse: 0.0019 - val_dense_6_mse: 0.0011
# Epoch 47/100
# 52800/52840 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 6.8131e-04 - dense_6_loss: 9.9641e-04 - dense_5_mse: 6.8131e-04 - dense_6_mse: 9.9641e-04
# Epoch 47: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 113us/sample - loss: 0.0017 - dense_5_loss: 6.8089e-04 - dense_6_loss: 9.9576e-04 - dense_5_mse: 6.8114e-04 - dense_6_mse: 9.9620e-04 - val_loss: 0.0028 - val_dense_5_loss: 9.1707e-04 - val_dense_6_loss: 0.0019 - val_dense_5_mse: 9.1705e-04 - val_dense_6_mse: 0.0019
# Epoch 48/100
# 52672/52840 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 6.8475e-04 - dense_6_loss: 0.0010 - dense_5_mse: 6.8475e-04 - dense_6_mse: 0.0010
# Epoch 48: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 94us/sample - loss: 0.0017 - dense_5_loss: 6.8494e-04 - dense_6_loss: 0.0010 - dense_5_mse: 6.8496e-04 - dense_6_mse: 0.0010 - val_loss: 0.0028 - val_dense_5_loss: 0.0010 - val_dense_6_loss: 0.0018 - val_dense_5_mse: 0.0010 - val_dense_6_mse: 0.0017
# Epoch 49/100
# 52640/52840 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 6.9790e-04 - dense_6_loss: 0.0011 - dense_5_mse: 6.9790e-04 - dense_6_mse: 0.0011
# Epoch 49: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 113us/sample - loss: 0.0018 - dense_5_loss: 6.9789e-04 - dense_6_loss: 0.0011 - dense_5_mse: 6.9786e-04 - dense_6_mse: 0.0011 - val_loss: 0.0028 - val_dense_5_loss: 0.0019 - val_dense_6_loss: 9.6433e-04 - val_dense_5_mse: 0.0019 - val_dense_6_mse: 9.6433e-04
# Epoch 50/100
# 52840/52840 [==============================] - ETA: 0s - loss: 0.0019 - dense_5_loss: 7.4975e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.4989e-04 - dense_6_mse: 0.0012
# Epoch 50: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 92us/sample - loss: 0.0019 - dense_5_loss: 7.4975e-04 - dense_6_loss: 0.0012 - dense_5_mse: 7.4989e-04 - dense_6_mse: 0.0012 - val_loss: 0.0042 - val_dense_5_loss: 0.0019 - val_dense_6_loss: 0.0023 - val_dense_5_mse: 0.0019 - val_dense_6_mse: 0.0023
# Epoch 51/100
# 52512/52840 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 7.3873e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.3873e-04 - dense_6_mse: 0.0011
# Epoch 51: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 112us/sample - loss: 0.0019 - dense_5_loss: 7.4007e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.3993e-04 - dense_6_mse: 0.0011 - val_loss: 0.0046 - val_dense_5_loss: 0.0020 - val_dense_6_loss: 0.0025 - val_dense_5_mse: 0.0020 - val_dense_6_mse: 0.0025
# Epoch 52/100
# 52448/52840 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 6.3839e-04 - dense_6_loss: 9.9293e-04 - dense_5_mse: 6.3839e-04 - dense_6_mse: 9.9293e-04
# Epoch 52: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 97us/sample - loss: 0.0016 - dense_5_loss: 6.3763e-04 - dense_6_loss: 9.8939e-04 - dense_5_mse: 6.3778e-04 - dense_6_mse: 9.8984e-04 - val_loss: 0.0027 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0016 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0016
# Epoch 53/100
# 52480/52840 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 6.8279e-04 - dense_6_loss: 0.0011 - dense_5_mse: 6.8279e-04 - dense_6_mse: 0.0011
# Epoch 53: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 112us/sample - loss: 0.0018 - dense_5_loss: 6.8095e-04 - dense_6_loss: 0.0011 - dense_5_mse: 6.8095e-04 - dense_6_mse: 0.0011 - val_loss: 0.0027 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0015 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0015
# Epoch 54/100
# 52512/52840 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 6.8950e-04 - dense_6_loss: 0.0010 - dense_5_mse: 6.8950e-04 - dense_6_mse: 0.0010
# Epoch 54: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 96us/sample - loss: 0.0017 - dense_5_loss: 6.9178e-04 - dense_6_loss: 0.0010 - dense_5_mse: 6.9143e-04 - dense_6_mse: 0.0010 - val_loss: 0.0025 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0012 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0012
# Epoch 55/100
# 52608/52840 [============================>.] - ETA: 0s - loss: 0.0018 - dense_5_loss: 6.9791e-04 - dense_6_loss: 0.0011 - dense_5_mse: 6.9791e-04 - dense_6_mse: 0.0011
# Epoch 55: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 117us/sample - loss: 0.0018 - dense_5_loss: 6.9657e-04 - dense_6_loss: 0.0011 - dense_5_mse: 6.9677e-04 - dense_6_mse: 0.0011 - val_loss: 0.0029 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0016 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0016
# Epoch 56/100
# 52704/52840 [============================>.] - ETA: 0s - loss: 0.0019 - dense_5_loss: 7.0821e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.0821e-04 - dense_6_mse: 0.0011
# Epoch 56: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 98us/sample - loss: 0.0019 - dense_5_loss: 7.0729e-04 - dense_6_loss: 0.0011 - dense_5_mse: 7.0749e-04 - dense_6_mse: 0.0011 - val_loss: 0.0027 - val_dense_5_loss: 0.0011 - val_dense_6_loss: 0.0016 - val_dense_5_mse: 0.0011 - val_dense_6_mse: 0.0016
# Epoch 57/100
# 52840/52840 [==============================] - ETA: 0s - loss: 0.0016 - dense_5_loss: 6.4544e-04 - dense_6_loss: 9.9112e-04 - dense_5_mse: 6.4542e-04 - dense_6_mse: 9.9092e-04
# Epoch 57: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 119us/sample - loss: 0.0016 - dense_5_loss: 6.4544e-04 - dense_6_loss: 9.9112e-04 - dense_5_mse: 6.4542e-04 - dense_6_mse: 9.9092e-04 - val_loss: 0.0034 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0022 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0022
# Epoch 58/100
# 52832/52840 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 6.2577e-04 - dense_6_loss: 0.0010 - dense_5_mse: 6.2577e-04 - dense_6_mse: 0.0010
# Epoch 58: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 98us/sample - loss: 0.0017 - dense_5_loss: 6.2550e-04 - dense_6_loss: 0.0010 - dense_5_mse: 6.2571e-04 - dense_6_mse: 0.0010 - val_loss: 0.0024 - val_dense_5_loss: 0.0013 - val_dense_6_loss: 0.0011 - val_dense_5_mse: 0.0013 - val_dense_6_mse: 0.0011
# Epoch 59/100
# 52840/52840 [==============================] - ETA: 0s - loss: 0.0015 - dense_5_loss: 6.0071e-04 - dense_6_loss: 9.1016e-04 - dense_5_mse: 6.0065e-04 - dense_6_mse: 9.1057e-04
# Epoch 59: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 120us/sample - loss: 0.0015 - dense_5_loss: 6.0071e-04 - dense_6_loss: 9.1016e-04 - dense_5_mse: 6.0065e-04 - dense_6_mse: 9.1057e-04 - val_loss: 0.0026 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0015 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0015
# Epoch 60/100
# 52768/52840 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 6.2821e-04 - dense_6_loss: 8.7395e-04 - dense_5_mse: 6.2821e-04 - dense_6_mse: 8.7395e-04
# Epoch 60: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 95us/sample - loss: 0.0015 - dense_5_loss: 6.2932e-04 - dense_6_loss: 8.7513e-04 - dense_5_mse: 6.2901e-04 - dense_6_mse: 8.7543e-04 - val_loss: 0.0026 - val_dense_5_loss: 0.0015 - val_dense_6_loss: 0.0010 - val_dense_5_mse: 0.0015 - val_dense_6_mse: 0.0010
# Epoch 61/100
# 52576/52840 [============================>.] - ETA: 0s - loss: 0.0017 - dense_5_loss: 6.4359e-04 - dense_6_loss: 0.0010 - dense_5_mse: 6.4359e-04 - dense_6_mse: 0.0010
# Epoch 61: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 111us/sample - loss: 0.0017 - dense_5_loss: 6.4347e-04 - dense_6_loss: 0.0010 - dense_5_mse: 6.4359e-04 - dense_6_mse: 0.0010 - val_loss: 0.0031 - val_dense_5_loss: 0.0018 - val_dense_6_loss: 0.0013 - val_dense_5_mse: 0.0018 - val_dense_6_mse: 0.0013
# Epoch 62/100
# 52512/52840 [============================>.] - ETA: 0s - loss: 0.0016 - dense_5_loss: 6.1370e-04 - dense_6_loss: 9.8335e-04 - dense_5_mse: 6.1370e-04 - dense_6_mse: 9.8335e-04
# Epoch 62: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 5s 92us/sample - loss: 0.0016 - dense_5_loss: 6.1381e-04 - dense_6_loss: 9.8011e-04 - dense_5_mse: 6.1359e-04 - dense_6_mse: 9.8041e-04 - val_loss: 0.0033 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0021 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0021
# Epoch 63/100
# 52736/52840 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 6.0973e-04 - dense_6_loss: 9.0420e-04 - dense_5_mse: 6.0973e-04 - dense_6_mse: 9.0420e-04
# Epoch 63: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 7s 126us/sample - loss: 0.0015 - dense_5_loss: 6.0936e-04 - dense_6_loss: 9.0263e-04 - dense_5_mse: 6.0937e-04 - dense_6_mse: 9.0304e-04 - val_loss: 0.0026 - val_dense_5_loss: 0.0017 - val_dense_6_loss: 8.5281e-04 - val_dense_5_mse: 0.0017 - val_dense_6_mse: 8.5318e-04
# Epoch 64/100
# 52704/52840 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 6.1625e-04 - dense_6_loss: 8.7838e-04 - dense_5_mse: 6.1625e-04 - dense_6_mse: 8.7838e-04
# Epoch 64: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 7s 127us/sample - loss: 0.0015 - dense_5_loss: 6.1620e-04 - dense_6_loss: 8.7699e-04 - dense_5_mse: 6.1622e-04 - dense_6_mse: 8.7736e-04 - val_loss: 0.0027 - val_dense_5_loss: 0.0015 - val_dense_6_loss: 0.0012 - val_dense_5_mse: 0.0015 - val_dense_6_mse: 0.0012
# Epoch 65/100
# 52704/52840 [============================>.] - ETA: 0s - loss: 0.0015 - dense_5_loss: 6.0388e-04 - dense_6_loss: 9.2029e-04 - dense_5_mse: 6.0388e-04 - dense_6_mse: 9.2029e-04
# Epoch 65: val_loss did not improve from 0.00229
# 52840/52840 [==============================] - 6s 113us/sample - loss: 0.0015 - dense_5_loss: 6.0326e-04 - dense_6_loss: 9.1855e-04 - dense_5_mse: 6.0334e-04 - dense_6_mse: 9.1890e-04 - val_loss: 0.0023 - val_dense_5_loss: 0.0012 - val_dense_6_loss: 0.0011 - val_dense_5_mse: 0.0012 - val_dense_6_mse: 0.0011
# Epoch 65: early stopping
# ---Training time: 373.52234554 seconds ---

# %%
# # Save the model
# print(model.summary())
# plot_model(model, show_shapes=True)
# model.save('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/Reference_p5270/Reference/DD_Transfer_model_70_10_20.h5')

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)[0,] 
y_predtrain_V =np.array(y_predtrain)[1,] 

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS) 
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS)) 

train_r2_V = r2_score(Y_train_V,y_predtrain_V ) 
train_rmse_V = np.sqrt(mean_squared_error(Y_train_V, y_predtrain_V )) 

# Model Performance: Validation 
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)[0,] 
y_predval_V = np.array(y_predval)[1,] 

val_r2_SS = r2_score(Y_val_SS, y_predval_SS) 
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS)) 

val_r2_V = r2_score(Y_val_V, y_predval_V) 
val_rmse_V = np.sqrt(mean_squared_error(Y_val_V, y_predval_V)) 

# Model Performance: Testing 
y_predtest = model.predict([x_test])
y_predtest_SS =np.array(y_predtest)[0,] 
y_predtest_V = np.array(y_predtest)[1,] 

test_r2_SS = r2_score(y_test_SS,y_predtest_SS) 
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS)) 

test_r2_V = r2_score(y_test_V,y_predtest_V) 
test_rmse_V = np.sqrt(mean_squared_error(y_test_V, y_predtest_V)) 

# Print R2 Results 
print("R2 scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_r2_SS , train_r2_V))
print("R2 scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_r2_SS , val_r2_V))
print("R2 scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_r2_SS , test_r2_V))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f, Train (V) - %0.5f" %(train_rmse_SS , train_rmse_V))
print("RMSE scores: Validation (SS) - %0.5f, Validation (V) - %0.5f" %(val_rmse_SS , val_rmse_V))
print("RMSE scores: Testing (SS) - %0.5f, Testing (V) - %0.5f" %(test_rmse_SS , test_rmse_V))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# R2 scores: Train (SS) - 0.98535, Train (V) - 0.92812
# R2 scores: Validation (SS) - 0.97623, Validation (V) - 0.90141
# R2 scores: Testing (SS) - 0.94573, Testing (V) - 0.83772
# RMSE scores: Train (SS) - 0.02074, Train (V) - 0.02611
# RMSE scores: Validation (SS) - 0.03030, Validation (V) - 0.03800
# RMSE scores: Testing (SS) - 0.04486, Testing (V) - 0.04736

# %%
# Inverse scaling: SS 
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# Inverse scaling: V
Y_train_V = scaler_v.inverse_transform(Y_train_V)
Y_val_V = scaler_v.inverse_transform(Y_val_V)
y_test_V = scaler_v.inverse_transform(y_test_V)
y_predtrain_V = scaler_v.inverse_transform(y_predtrain_V)
y_predval_V = scaler_v.inverse_transform(y_predval_V)
y_predtest_V = scaler_v.inverse_transform(y_predtest_V)

# %%
# Overall plot: SS & V 
ttime = df['Time'][n_steps:]
t1, testtime = train_test_split(ttime, test_size=0.2, shuffle=False)
traintime, valtime = train_test_split(t1, test_size=0.125, shuffle=False)

traintime = traintime[39629:92469] 

fig = plt.figure(1, figsize=(20,6))
plt.plot(ttime, ydf_SS)
plt.plot(traintime, y_predtrain_SS)
plt.plot(valtime, y_predval_SS)
plt.plot(testtime, y_predtest_SS)
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

fig = plt.figure(2, figsize=(20,6))
plt.plot(ttime, ydf_V)
plt.plot(traintime, y_predtrain_V)
plt.plot(valtime,  y_predval_V)
plt.plot(testtime, y_predtest_V)
plt.xlabel('Time (s)')
plt.ylabel('Slip Rate (um/s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

# %%
# Individual plot: SS

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Shear Stress (MPa)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SS, y_predtrain_SS, 'Training data', '')
results_plot(2, valtime, Y_val_SS, y_predval_SS, 'Validation data', 'g')
results_plot(3, testtime, y_test_SS, y_predtest_SS, 'Testing data', 'r')

# %%
# Individual plot: V

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Slip Rate (um/s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_V, y_predtrain_V, 'Training data', '')
results_plot(2, valtime, Y_val_V, y_predval_V, 'Validation data', 'g')
results_plot(3, testtime, y_test_V, y_predtest_V, 'Testing data', 'r')

# %%
# # Extract Data

# # Time 
# savetxt('Whole_time.csv', ttime, delimiter=',')
# savetxt('traintime.csv', traintime, delimiter=',')
# savetxt('valtime.csv', valtime, delimiter=',')
# savetxt('testtime.csv', testtime, delimiter=',')

# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# # V
# savetxt('Y_train_V.csv', Y_train_V, delimiter=',')
# savetxt('Y_val_V.csv', Y_val_V, delimiter=',')
# savetxt('y_test_V.csv', y_test_V, delimiter=',')
# savetxt('y_predtrain_V.csv', y_predtrain_V, delimiter=',')
# savetxt('y_predval_V.csv', y_predval_V, delimiter=',')
# savetxt('y_predtest_V.csv', y_predtest_V, delimiter=',')

# # Download
# files.download('Whole_time.csv')
# files.download('traintime.csv')
# files.download('valtime.csv')
# files.download('testtime.csv')

# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')

# files.download('Y_train_V.csv')
# files.download('Y_val_V.csv')
# files.download('y_test_V.csv')
# files.download('y_predtrain_V.csv')
# files.download('y_predval_V.csv')
# files.download('y_predtest_V.csv')
